# %% [markdown]
# # Pull data and store in MongoDB

# %% [markdown]
# ## Get location info

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import os
chromedriver = "/Applications/chromedriver"
os.environ["webdriver.chrome.driver"] = chromedriver
driver = webdriver.Chrome(chromedriver)

# %%
def get_stations(soup):
    stations = []
    for ele in soup.find_all(class_ = 'stationname'):
        stations.append(ele.find('a').string)
    return stations

def get_station_ids(soup):
    station_ids = []
    for ele in soup.find_all(class_ = 'stationid'):
        station_ids.append(ele.text)
    return station_ids
    
def get_lats(soup):
    lats = []
    for ele in soup.find_all(class_ = 'latitude'):
        lats.append(ele.text)
        lats = [lat.replace("+","") for lat in lats]
    return lats

def get_longs(soup):
    longs = []
    for ele in soup.find_all(class_ = 'longitude'):
        longs.append(ele.text)
    return longs

# %%
import time
from bs4 import BeautifulSoup
import requests
url_list = ['https://tidesandcurrents.noaa.gov/tide_predictions.html?gid=1393#listing', 
            'https://tidesandcurrents.noaa.gov/tide_predictions.html?gid=1409#listing',
           'https://tidesandcurrents.noaa.gov/tide_predictions.html?gid=1415#listing']
station_dict = {}
for url in url_list:
    driver.get(url)
    time.sleep(10)
    soup = BeautifulSoup(driver.page_source, 'html.parser')
    station_dict['station_name'] = get_stations(soup)
    station_dict['station_id'] = get_station_ids(soup)
    station_dict['lat'] = get_lats(soup)
    station_dict['long'] = get_longs(soup)
    driver.execute_script("window.stop();")

# %%
assert len(station_dict['station_name'])==len(station_dict['station_id']) == \
len(station_dict['lat']) == len(station_dict['long']), \
f"Lengths of dictionary elements differ: \n\
Num Station Names: {len(station_dict['station_name'])} \n\
Num Station Ids: {len(station_dict['station_id'])} \n\
Num Latitudes: {len(station_dict['lat'])} \n\
Num Longitudes: {len(station_dict['long'])}"

# %%
stations = []
for idx, val in enumerate(station_dict['station_name']):
    dict_to_append = {'station_name':station_dict['station_name'][idx],
                      'station_id':station_dict['station_id'][idx],
                      'lat':station_dict['lat'][idx],
                      'long':station_dict['long'][idx]
                      }
    stations.append(dict_to_append)

# %% [markdown]
# ## Get weather data and put into MongoDB

# %%
#get weather data for the next 72 hours
import requests
def get_weather_data(stations):
    weather_list = []
    weather_url = "https://weatherbit-v1-mashape.p.rapidapi.com/forecast/hourly"
    for station in stations:
        querystring = {"lat":station['lat'],"lon":station['long'],"hours":"72"}
        headers = {
            "X-RapidAPI-Key": "1282a0348bmsh6030279122a830ap16b70fjsn3c47099439d6",
            "X-RapidAPI-Host": "weatherbit-v1-mashape.p.rapidapi.com"
        }
        weather_dict = {'station_name':station['station_name'],
                        'station_id':station['station_id'],
                        'lat':station['lat'],
                        'long':station['long'],
                        'response':requests.request("GET", weather_url, headers=headers, params=querystring).json()['data']
                       }
        weather_list.append(weather_dict)
    return weather_list

# %%
weather_data = get_weather_data(stations)

# %%
# !mongod --dbpath ~/data/paddleboard_db

# %%
# !brew services start mongodb/brew/mongodb-community
# Out:
# ==> Successfully started `mongodb-community` (label: homebrew.mxcl.mongodb-commu

# %%
import pymongo
from pymongo import MongoClient
client = MongoClient()

# %%
client.list_database_names()
# Out:
# ['admin', 'config', 'local']

# %%
db = client["paddleboard"]
weather = db["weather"]
weather.insert_many(weather_data)

# %% [markdown]
# ## Get tide data and put into MongoDB

# %%
def get_tides_data(stations):
    tides_response = []
    for station in stations:
        tides_url = "https://api.tidesandcurrents.noaa.gov/mdapi/prod/webapi/stations/{}.json?expand=products".format(station['station_id'])
        tides_dict = {'station_name':station['station_name'],
                      'station_id':station['station_id'],
                      'lat':station['lat'],
                      'long':station['long'],
                      'response':requests.request("GET", tides_url).json()
                     }
        tides_response.append(tides_dict)
    return tides_response

# %%
tides_data = get_tides_data(stations)

# %%
#put tides data in MongoDB
tides = db["tides"]
tides.insert_many(tides_data)

# %% [markdown]
# ## Get air quality data and put into MongoDB

# %%
def get_air_quality_data(stations):
    aqi_list = []
    for station in stations:
        aqi_url = "http://api.openweathermap.org/data/2.5/air_pollution/forecast?lat={}&lon={}&appid={}".format(
            station['lat'], station['long'], '12b57316a4ce5ebac5e0386d9ee999be'
        )
        aqi_dict = {'station_name':station['station_name'],
                    'station_id':station['station_id'],
                    'lat':station['lat'],
                    'long':station['long'],
                    'response':requests.request("GET", aqi_url).json()
             }
        aqi_list.append(aqi_dict)
    print(aqi_url) #checking one output of the url format to make sure it's working smoothly
    return aqi_list

# %%
aqi_data = get_air_quality_data(stations)
# Out:
# http://api.openweathermap.org/data/2.5/air_pollution/forecast?lat=48.7867&lon=-122.9700&appid=12b57316a4ce5ebac5e0386d9ee999be

# %%
#put AQI data in MongoDB
aqi = db["aqi"]
aqi.insert_many(aqi_data)

# %%
print("Databases:", client.list_database_names())
print("Collections:", db.list_collection_names())
# Out:
# Databases: ['admin', 'config', 'local', 'paddleboard']
# Collections: ['tides', 'aqi', 'weather']

# %% [markdown]
# ## Shut down MongoDB

# %%
# !brew services stop mongodb/brew/mongodb-community
# Out:
# Stopping `mongodb-community`... (might take a while)
# ==> Successfully stopped `mongodb-community` (label: homebrew.mxcl.mongodb-commu

# %% [markdown]
# ## Extras

# %%
test = db['tides']
cursor = test.find()
list_cur = list(cursor)

# %%
tides_test = list_cur

# %%
tides_test[0]['response']['stations'][0]['products']['products'][0]['value']
# Out:
# 'https://tidesandcurrents.noaa.gov/noaatidepredictions.html?id=9440574'

# %%
tides_test[0]
# Out:
# {'_id': ObjectId('62f0398ac868aa58a7095033'),
#  'station_name': 'Columbia River entrance (N. Jetty)',
#  'station_id': '9440574',
#  'lat': '46.2733',
#  'long': '-124.0720',
#  'response': {'count': 1,
#   'units': None,
#   'stations': [{'tidal': True,
#     'greatlakes': False,
#     'shefcode': None,
#     'details': {'self': 'https://api.tidesandcurrents.noaa.gov/mdapi/prod/webapi/stations/9440574/details.json'},
#     'sensors': {'self': 'https://api.tidesandcurrents.noaa.gov/mdapi/prod/webapi/stations/9440574/sensors.json'},
#     'floodlevels': {'self': 'https://api.tidesandcurrents.noaa.gov/mdapi/prod/webapi/stations/9440574/floodlevels.json'},
#     'datums': {'self': 'https://api.tidesandcurrents.noaa.gov/mdapi/prod/webapi/stations/9440574/datums.json'},
#     'supersededdatums': {'self': 'https://api.tidesandcurrents.noaa.gov/mdapi/prod/webapi/stations/9440574/supersededdatums.json'},
#     'harmonicConstituents': {'self': 'https://api.tidesandcurrents.noaa.gov/mdapi/prod/webapi/stations/9440574/harcon.json'},
#     'benchmarks': {'self': 'https://api.tidesandcurrents.noaa.gov/mdapi/prod/webapi/stations/9440574/benchmarks.json'},
#     'tidePredOffsets': {'self': 'https://api.tidesandcurrents.noaa.gov/mdapi/prod/webapi/stations/9440574/tidepredoffsets.json'},
#     'ofsMapOffsets': {'self': 'https://api.tidesandcurrents.noaa.gov/mdapi/prod/webapi/stations/9440574/ofsmapoffsets.json'},
#     'state': 'WA',
#     'timezone': 'PST',
#     'timezonecorr': -8,
#     'observedst': True,
#     'stormsurge': False,
#     'nearby': {'self': 'https://api.tidesandcurrents.noaa.gov/mdapi/prod/webapi/stations/9440574/nearby.json'},
#     'forecast': False,
#     'outlook': False,
#     'nonNavigational': False,
#     'id': '9440574',
#     'name': 'NORTH JETTY',
#     'lat': 46.2733,
#     'lng': -124.072,
#     'affiliations': '',
#     'portscode': None,
#     'products': {'products': [{'name': 'Tide Predictions',
#        'value': 'https://tidesandcurrents.noaa.gov/noaatidepredictions.html?id=9440574'},
#       {'name': 'OFS',
#        'value': 'https://tidesandcurrents.noaa.gov/ofs/ofs_station.html?stname=North Jetty&ofs=cre&stnid=9440574&subdomain=of_ba'},
#       {'name': 'Benchmarks',
#        'value': 'https://tidesandcurrents.noaa.gov/benchmarks.html?id=9440574'},
#       {'name': 'Datums',
#        'value': 'https://tidesandcurrents.noaa.gov/datums.html?id=9440574'},
#       {'name': 'OFS Code', 'value': 'cre'},
#       {'name': 'OFS Name', 'value': 'Columbia River Estuary'}],
#      'self': 'https://api.tidesandcurrents.noaa.gov/mdapi/prod/webapi/stations/9440574/products.json'},
#     'disclaimers': {'self': 'https://api.tidesandcurrents.noaa.gov/mdapi/prod/webapi/stations/9440574/disclaimers.json'},
#     'notices': {'self': 'https://api.tidesandcurrents.noaa.gov/mdapi/prod/webapi/stations/9440574/notices.json'},
#     'self': 'https://api.tidesandcurrents.noaa.gov/mdapi/prod/webapi/stations/9440574.json',
#     'expand': 'details,sensors,floodlevels,datums,harcon,tidepredoffsets,ofsmapoffsets,products,disclaimers,notices',
#     'tideType': 'Mixed'}],
#   'self': None}}

# %%
latlong
# Out:
# [46.2733, -124.072]

# %%
aqi_test[1]
# Out:
# {'_id': ObjectId('62f0397dc868aa58a7094f79'),
#  'station_name': 'Cape Disappointment',
#  'station_id': '9440581',
#  'lat': '46.2810',
#  'long': '-124.0463',
#  'response': [{'wind_cdir': 'N',
#    'rh': 60,
#    'pod': 'd',
#    'timestamp_utc': '2022-08-07T23:00:00',
#    'pres': 1012.5,
#    'solar_rad': 682.645,
#    'ozone': 308.3,
#    'weather': {'icon': 'c01d', 'code': 800, 'description': 'Clear Sky'},
#    'wind_gust_spd': 8.59,
#    'timestamp_local': '2022-08-07T16:00:00',
#    'snow_depth': 0,
#    'clouds': 0,
#    'ts': 1659913200,
#    'wind_spd': 5.81,
#    'pop': 0,
#    'wind_cdir_full': 'north',
#    'slp': 1014.5,
#    'dni': 853.55,
#    'dewpt': 15.5,
#    'snow': 0,
#    'uv': 5.4,
#    'wind_dir': 2,
#    'clouds_hi': 0,
#    'precip': 0,
#    'vis': 31.296,
#    'dhi': 108.54,
#    'app_temp': 23.8,
#    'datetime': '2022-08-07:23',
#    'temp': 23.8,
#    'ghi': 710.51,
#    'clouds_mid': 0,
#    'clouds_low': 0},
#   {'wind_cdir': 'N',
#    'rh': 55,
#    'pod': 'd',
#    'timestamp_utc': '2022-08-08T00:00:00',
#    'pres': 1012.5,
#    'solar_rad': 543.271,
#    'ozone': 308.5,
#    'weather': {'icon': 'c01d', 'code': 800, 'description': 'Clear Sky'},
#    'wind_gust_spd': 9.52,
#    'timestamp_local': '2022-08-07T17:00:00',
#    'snow_depth': 0,
#    'clouds': 0,
#    'ts': 1659916800,
#    'wind_spd': 6.09,
#    'pop': 0,
#    'wind_cdir_full': 'north',
#    'slp': 1014,
#    'dni': 802.38,
#    'dewpt': 12.6,
#    'snow': 0,
#    'uv': 3.7,
#    'wind_dir': 5,
#    'clouds_hi': 0,
#    'precip': 0,
#    'vis': 34.688,
#    'dhi': 98.9,
#    'app_temp': 21.8,
#    'datetime': '2022-08-08:00',
#    'temp': 22.1,
#    'ghi': 562.97,
#    'clouds_mid': 0,
#    'clouds_low': 0},
#   {'wind_cdir': 'N',
#    'rh': 61,
#    'pod': 'd',
#    'timestamp_utc': '2022-08-08T01:00:00',
#    'pres': 1013,
#    'solar_rad': 376.448,
#    'ozone': 309,
#    'weather': {'icon': 'c01d', 'code': 800, 'description': 'Clear Sky'},
#    'wind_gust_spd': 8.93,
#    'timestamp_local': '2022-08-07T18:00:00',
#    'snow_depth': 0,
#    'clouds': 0,
#    'ts': 1659920400,
#    'wind_spd': 5.67,
#    'pop': 0,
#    'wind_cdir_full': 'north',
#    'slp': 1014,
#    'dni': 719.69,
#    'dewpt': 13,
#    'snow': 0,
#    'uv': 2.4,
#    'wind_dir': 5,
#    'clouds_hi': 0,
#    'precip': 0,
#    'vis': 30,
#    'dhi': 85.06,
#    'app_temp': 20.5,
#    'datetime': '2022-08-08:01',
#    'temp': 20.8,
#    'ghi': 390.32,
#    'clouds_mid': 0,
#    'clouds_low': 0},
#   {'wind_cdir': 'N',
#    'rh': 62,
#    'pod': 'd',
#    'timestamp_utc': '2022-08-08T02:00:00',
#    'pres': 1012.5,
#    'solar_rad': 203.627,
#    'ozone': 308.5,
#    'weather': {'icon': 'c01d', 'code': 800, 'description': 'Clear Sky'},
#    'wind_gust_spd': 7.18,
#    'timestamp_local': '2022-08-07T19:00:00',
#    'snow_depth': 0,
#    'clouds': 0,
#    'ts': 1659924000,
#    'wind_spd': 5.11,
#    'pop': 0,
#    'wind_cdir_full': 'north',
#    'slp': 1014.5,
#    'dni': 579.5,
#    'dewpt': 12.5,
#    'snow': 0,
#    'uv': 1.7,
#    'wind_dir': 6,
#    'clouds_hi': 0,
#    'precip': 0,
#    'vis': 29.088,
#    'dhi': 65.35,
#    'app_temp': 19.6,
#    'datetime': '2022-08-08:02',
#    'temp': 20,
#    'ghi': 210.9,
#    'clouds_mid': 0,
#    'clouds_low': 0},
#   {'wind_cdir': 'N',
#    'rh': 65,
#    'pod': 'd',
#    'timestamp_utc': '2022-08-08T03:00:00',
#    'pres': 1012,
#    'solar_rad': 50.0318,
#    'ozone': 307.8,
#    'weather': {'icon': 'c01d', 'code': 800, 'description': 'Clear Sky'},
#    'wind_gust_spd': 7,
#    'timestamp_local': '2022-08-07T20:00:00',
#    'snow_depth': 0,
#    'clouds': 0,
#    'ts': 1659927600,
#    'wind_spd': 4.45,
#    'pop': 0,
#    'wind_cdir_full': 'north',
#    'slp': 1015,
#    'dni': 292.88,
#    'dewpt': 11.3,
#    'snow': 0,
#    'uv': 1.5,
#    'wind_dir': 5,
#    'clouds_hi': 0,
#    'precip': 0,
#    'vis': 26.592,
#    'dhi': 34.39,
#    'app_temp': 18,
#    'datetime': '2022-08-08:03',
#    'temp': 18,
#    'ghi': 51.7,
#    'clouds_mid': 0,
#    'clouds_low': 0},
#   {'wind_cdir': 'NNW',
#    'rh': 69,
#    'pod': 'n',
#    'timestamp_utc': '2022-08-08T04:00:00',
#    'pres': 1012.5,
#    'solar_rad': 0,
#    'ozone': 307,
#    'weather': {'icon': 'c01n', 'code': 800, 'description': 'Clear Sky'},
#    'wind_gust_spd': 5.61,
#    'timestamp_local': '2022-08-07T21:00:00',
#    'snow_depth': 0,
#    'clouds': 0,
#    'ts': 1659931200,
#    'wind_spd': 2.38,
#    'pop': 0,
#    'wind_cdir_full': 'north-northwest',
#    'slp': 1015,
#    'dni': 0,
#    'dewpt': 11,
#    'snow': 0,
#    'uv': 0,
#    'wind_dir': 359,
#    'clouds_hi': 0,
#    'precip': 0,
#    'vis': 23.888,
#    'dhi': 0,
#    'app_temp': 16.7,
#    'datetime': '2022-08-08:04',
#    'temp': 16.7,
#    'ghi': 0,
#    'clouds_mid': 0,
#    'clouds_low': 0},
#   {'wind_cdir': 'W',
#    'rh': 85,
#    'pod': 'n',
#    'timestamp_utc': '2022-08-08T05:00:00',
#    'pres': 1013,
#    'solar_rad': 0,
#    'ozone': 305,
#    'weather': {'icon': 'c02n', 'code': 801, 'description': 'Few clouds'},
#    'wind_gust_spd': 2.2,
#    'timestamp_local': '2022-08-07T22:00:00',
#    'snow_depth': 0,
#    'clouds': 3,
#    'ts': 1659934800,
#    'wind_spd': 2.2,
#    'pop': 0,
#    'wind_cdir_full': 'west',
#    'slp': 1016,
#    'dni': 0,
#    'dewpt': 12.7,
#    'snow': 0,
#    'uv': 0,
#    'wind_dir': 271,
#    'clouds_hi': 0,
#    'precip': 0,
#    'vis': 15.896,
#    'dhi': 0,
#    'app_temp': 15.2,
#    'datetime': '2022-08-08:05',
#    'temp': 15.2,
#    'ghi': 0,
#    'clouds_mid': 0,
#    'clouds_low': 3},
#   {'wind_cdir': 'SW',
#    'rh': 90,
#    'pod': 'n',
#    'timestamp_utc': '2022-08-08T06:00:00',
#    'pres': 1013.5,
#    'solar_rad': 0,
#    'ozone': 304.5,
#    'weather': {'icon': 'c02n', 'code': 801, 'description': 'Few clouds'},
#    'wind_gust_spd': 3.87,
#    'timestamp_local': '2022-08-07T23:00:00',
#    'snow_depth': 0,
#    'clouds': 16,
#    'ts': 1659938400,
#    'wind_spd': 3.22,
#    'pop': 0,
#    'wind_cdir_full': 'southwest',
#    'slp': 1016,
#    'dni': 0,
#    'dewpt': 13.1,
#    'snow': 0,
#    'uv': 0,
#    'wind_dir': 234,
#    'clouds_hi': 0,
#    'precip': 0,
#    'vis': 13.896,
#    'dhi': 0,
#    'app_temp': 14.7,
#    'datetime': '2022-08-08:06',
#    'temp': 14.7,
#    'ghi': 0,
#    'clouds_mid': 0,
#    'clouds_low': 16},
#   {'wind_cdir': 'SW',
#    'rh': 92,
#    'pod': 'n',
#    'timestamp_utc': '2022-08-08T07:00:00',
#    'pres': 1013.5,
#    'solar_rad': 0,
#    'ozone': 305.3,
#    'weather': {'icon': 'c02n', 'code': 801, 'description': 'Few clouds'},
#    'wind_gust_spd': 6.05,
#    'timestamp_local': '2022-08-08T00:00:00',
#    'snow_depth': 0,
#    'clouds': 14,
#    'ts': 1659942000,
#    'wind_spd': 3.92,
#    'pop': 0,
#    'wind_cdir_full': 'southwest',
#    'slp': 1016.5,
#    'dni': 0,
#    'dewpt': 13.3,
#    'snow': 0,
#    'uv': 0,
#    'wind_dir': 217,
#    'clouds_hi': 0,
#    'precip': 0,
#    'vis': 13.296,
#    'dhi': 0,
#    'app_temp': 14.6,
#    'datetime': '2022-08-08:07',
#    'temp': 14.6,
#    'ghi': 0,
#    'clouds_mid': 0,
#    'clouds_low': 14},
#   {'wind_cdir': 'SW',
#    'rh': 97,
#    'pod': 'n',
#    'timestamp_utc': '2022-08-08T08:00:00',
#    'pres': 1014,
#    'solar_rad': 0,
#    'ozone': 305.8,
#    'weather': {'icon': 'c02n', 'code': 802, 'description': 'Scattered clouds'},
#    'wind_gust_spd': 6.07,
#    'timestamp_local': '2022-08-08T01:00:00',
#    'snow_depth': 0,
#    'clouds': 36,
#    'ts': 1659945600,
#    'wind_spd': 3.75,
#    'pop': 0,
#    'wind_cdir_full': 'southwest',
#    'slp': 1016,
#    'dni': 0,
#    'dewpt': 13.4,
#    'snow': 0,
#    'uv': 0,
#    'wind_dir': 220,
#    'clouds_hi': 0,
#    'precip': 0,
#    'vis': 12.2,
#    'dhi': 0,
#    'app_temp': 13.9,
#    'datetime': '2022-08-08:08',
#    'temp': 13.9,
#    'ghi': 0,
#    'clouds_mid': 0,
#    'clouds_low': 36},
#   {'wind_cdir': 'SW',
#    'rh': 99,
#    'pod': 'n',
#    'timestamp_utc': '2022-08-08T09:00:00',
#    'pres': 1014.5,
#    'solar_rad': 0,
#    'ozone': 305,
#    'weather': {'icon': 'c04n', 'code': 804, 'description': 'Overcast clouds'},
#    'wind_gust_spd': 4.61,
#    'timestamp_local': '2022-08-08T02:00:00',
#    'snow_depth': 0,
#    'clouds': 100,
#    'ts': 1659949200,
#    'wind_spd': 2.92,
#    'pop': 0,
#    'wind_cdir_full': 'southwest',
#    'slp': 1015.5,
#    'dni': 0,
#    'dewpt': 13.3,
#    'snow': 0,
#    'uv': 0,
#    'wind_dir': 214,
#    'clouds_hi': 0,
#    'precip': 0,
#    'vis': 0.3,
#    'dhi': 0,
#    'app_temp': 13.5,
#    'datetime': '2022-08-08:09',
#    'temp': 13.5,
#    'ghi': 0,
#    'clouds_mid': 0,
#    'clouds_low': 100},
#   {'wind_cdir': 'SSW',
#    'rh': 97,
#    'pod': 'n',
#    'timestamp_utc': '2022-08-08T10:00:00',
#    'pres': 1014.5,
#    'solar_rad': 0,
#    'ozone': 303.8,
#    'weather': {'icon': 'c04n', 'code': 804, 'description': 'Overcast clouds'},
#    'wind_gust_spd': 4,
#    'timestamp_local': '2022-08-08T03:00:00',
#    'snow_depth': 0,
#    'clouds': 100,
#    'ts': 1659952800,
#    'wind_spd': 3.12,
#    'pop': 0,
#    'wind_cdir_full': 'south-southwest',
#    'slp': 1015.5,
#    'dni': 0,
#    'dewpt': 12.9,
#    'snow': 0,
#    'uv': 0,
#    'wind_dir': 204,
#    'clouds_hi': 0,
#    'precip': 0,
#    'vis': 0.3,
#    'dhi': 0,
#    'app_temp': 13.3,
#    'datetime': '2022-08-08:10',
#    'temp': 13.3,
#    'ghi': 0,
#    'clouds_mid': 0,
#    'clouds_low': 100},
#   {'wind_cdir': 'SSW',
#    'rh': 100,
#    'pod': 'n',
#    'timestamp_utc': '2022-08-08T11:00:00',
#    'pres': 1014.5,
#    'solar_rad': 0,
#    'ozone': 304,
#    'weather': {'icon': 'c04n', 'code': 804, 'description': 'Overcast clouds'},
#    'wind_gust_spd': 4.23,
#    'timestamp_local': '2022-08-08T04:00:00',
#    'snow_depth': 0,
#    'clouds': 100,
#    'ts': 1659956400,
#    'wind_spd': 3.22,
#    'pop': 0,
#    'wind_cdir_full': 'south-southwest',
#    'slp': 1015.5,
#    'dni': 0,
#    'dewpt': 12.7,
#    'snow': 0,
#    'uv': 0,
#    'wind_dir': 206,
#    'clouds_hi': 0,
#    'precip': 0,
#    'vis': 0,
#    'dhi': 0,
#    'app_temp': 12.7,
#    'datetime': '2022-08-08:11',
#    'temp': 12.7,
#    'ghi': 0,
#    'clouds_mid': 0,
#    'clouds_low': 100},
#   {'wind_cdir': 'SSW',
#    'rh': 100,
#    'pod': 'n',
#    'timestamp_utc': '2022-08-08T12:00:00',
#    'pres': 1014,
#    'solar_rad': 0,
#    'ozone': 302.8,
#    'weather': {'icon': 'c04n', 'code': 804, 'description': 'Overcast clouds'},
#    'wind_gust_spd': 4.14,
#    'timestamp_local': '2022-08-08T05:00:00',
#    'snow_depth': 0,
#    'clouds': 100,
#    'ts': 1659960000,
#    'wind_spd': 3.05,
#    'pop': 20,
#    'wind_cdir_full': 'south-southwest',
#    'slp': 1015.5,
#    'dni': 0,
#    'dewpt': 12.5,
#    'snow': 0,
#    'uv': 0,
#    'wind_dir': 208,
#    'clouds_hi': 0,
#    'precip': 0.0019989,
#    'vis': 0,
#    'dhi': 0,
#    'app_temp': 12.5,
#    'datetime': '2022-08-08:12',
#    'temp': 12.5,
#    'ghi': 0,
#    'clouds_mid': 0,
#    'clouds_low': 100},
#   {'wind_cdir': 'SSW',
#    'rh': 100,
#    'pod': 'n',
#    'timestamp_utc': '2022-08-08T13:00:00',
#    'pres': 1014.5,
#    'solar_rad': 0,
#    'ozone': 301.3,
#    'weather': {'icon': 'c04n', 'code': 804, 'description': 'Overcast clouds'},
#    'wind_gust_spd': 4.29,
#    'timestamp_local': '2022-08-08T06:00:00',
#    'snow_depth': 0,
#    'clouds': 100,
#    'ts': 1659963600,
#    'wind_spd': 3.15,
#    'pop': 20,
#    'wind_cdir_full': 'south-southwest',
#    'slp': 1015.5,
#    'dni': 0,
#    'dewpt': 12.5,
#    'snow': 0,
#    'uv': 0,
#    'wind_dir': 208,
#    'clouds_hi': 0,
#    'precip': 0.0019989,
#    'vis': 0,
#    'dhi': 0,
#    'app_temp': 12.5,
#    'datetime': '2022-08-08:13',
#    'temp': 12.5,
#    'ghi': 0,
#    'clouds_mid': 0,
#    'clouds_low': 100},
#   {'wind_cdir': 'SSW',
#    'rh': 100,
#    'pod': 'd',
#    'timestamp_utc': '2022-08-08T14:00:00',
#    'pres': 1014.5,
#    'solar_rad': 49.1351,
#    'ozone': 301,
#    'weather': {'icon': 'c04d', 'code': 804, 'description': 'Overcast clouds'},
#    'wind_gust_spd': 4.11,
#    'timestamp_local': '2022-08-08T07:00:00',
#    'snow_depth': 0,
#    'clouds': 100,
#    'ts': 1659967200,
#    'wind_spd': 3.03,
#    'pop': 20,
#    'wind_cdir_full': 'south-southwest',
#    'slp': 1016,
#    'dni': 391.35,
#    'dewpt': 12.6,
#    'snow': 0,
#    'uv': 0.5,
#    'wind_dir': 203,
#    'clouds_hi': 0,
#    'precip': 0.00299835,
#    'vis': 0,
#    'dhi': 44.02,
#    'app_temp': 12.6,
#    'datetime': '2022-08-08:14',
#    'temp': 12.6,
#    'ghi': 87.7,
#    'clouds_mid': 0,
#    'clouds_low': 100},
#   {'wind_cdir': 'SSW',
#    'rh': 100,
#    'pod': 'd',
#    'timestamp_utc': '2022-08-08T15:00:00',
#    'pres': 1015,
#    'solar_rad': 86.5575,
#    'ozone': 300.5,
#    'weather': {'icon': 'c04d', 'code': 804, 'description': 'Overcast clouds'},
#    'wind_gust_spd': 4.21,
#    'timestamp_local': '2022-08-08T08:00:00',
#    'snow_depth': 0,
#    'clouds': 100,
#    'ts': 1659970800,
#    'wind_spd': 3.07,
#    'pop': 20,
#    'wind_cdir_full': 'south-southwest',
#    'slp': 1016,
#    'dni': 623.06,
#    'dewpt': 12.7,
#    'snow': 0,
#    'uv': 0.6,
#    'wind_dir': 204,
#    'clouds_hi': 0,
#    'precip': 0.0019989,
#    'vis': 0,
#    'dhi': 71.05,
#    'app_temp': 12.7,
#    'datetime': '2022-08-08:15',
#    'temp': 12.7,
#    'ghi': 255.59,
#    'clouds_mid': 0,
#    'clouds_low': 100},
#   {'wind_cdir': 'SSW',
#    'rh': 100,
#    'pod': 'd',
#    'timestamp_utc': '2022-08-08T16:00:00',
#    'pres': 1015,
#    'solar_rad': 115.592,
#    'ozone': 300.3,
#    'weather': {'icon': 'c04d', 'code': 804, 'description': 'Overcast clouds'},
#    'wind_gust_spd': 4.2,
#    'timestamp_local': '2022-08-08T09:00:00',
#    'snow_depth': 0,
#    'clouds': 100,
#    'ts': 1659974400,
#    'wind_spd': 3.04,
#    'pop': 20,
#    'wind_cdir_full': 'south-southwest',
#    'slp': 1016,
#    'dni': 744.34,
#    'dewpt': 12.8,
#    'snow': 0,
#    'uv': 0.8,
#    'wind_dir': 207,
#    'clouds_hi': 0,
#    'precip': 0.0019989,
#    'vis': 0,
#    'dhi': 88.99,
#    'app_temp': 12.8,
#    'datetime': '2022-08-08:16',
#    'temp': 12.8,
#    'ghi': 435.03,
#    'clouds_mid': 0,
#    'clouds_low': 100},
#   {'wind_cdir': 'SSW',
#    'rh': 100,
#    'pod': 'd',
#    'timestamp_utc': '2022-08-08T17:00:00',
#    'pres': 1015.5,
#    'solar_rad': 138.31,
#    'ozone': 301.3,
#    'weather': {'icon': 'c04d', 'code': 804, 'description': 'Overcast clouds'},
#    'wind_gust_spd': 5.24,
#    'timestamp_local': '2022-08-08T10:00:00',
#    'snow_depth': 0,
#    'clouds': 100,
#    'ts': 1659978000,
#    'wind_spd': 3.78,
#    'pop': 20,
#    'wind_cdir_full': 'south-southwest',
#    'slp': 1016,
#    'dni': 817.47,
#    'dewpt': 13.2,
#    'snow': 0,
#    'uv': 1.3,
#    'wind_dir': 208,
#    'clouds_hi': 0,
#    'precip': 0.0019989,
#    'vis': 0,
#    'dhi': 101.64,
#    'app_temp': 13.2,
#    'datetime': '2022-08-08:17',
#    'temp': 13.2,
#    'ghi': 602.49,
#    'clouds_mid': 0,
#    'clouds_low': 100},
#   {'wind_cdir': 'SW',
#    'rh': 100,
#    'pod': 'd',
#    'timestamp_utc': '2022-08-08T18:00:00',
#    'pres': 1015.5,
#    'solar_rad': 154.903,
#    'ozone': 303,
#    'weather': {'icon': 'c04d', 'code': 804, 'description': 'Overcast clouds'},
#    'wind_gust_spd': 4.45,
#    'timestamp_local': '2022-08-08T11:00:00',
#    'snow_depth': 0,
#    'clouds': 100,
#    'ts': 1659981600,
#    'wind_spd': 3.27,
#    'pop': 0,
#    'wind_cdir_full': 'southwest',
#    'slp': 1016,
#    'dni': 862.92,
#    'dewpt': 13.6,
#    'snow': 0,
#    'uv': 1.8,
#    'wind_dir': 217,
#    'clouds_hi': 0,
#    'precip': 0,
#    'vis': 0.1,
#    'dhi': 110.38,
#    'app_temp': 13.6,
#    'datetime': '2022-08-08:18',
#    'temp': 13.6,
#    'ghi': 741.09,
#    'clouds_mid': 0,
#    'clouds_low': 100},
#   {'wind_cdir': 'SW',
#    'rh': 96,
#    'pod': 'd',
#    'timestamp_utc': '2022-08-08T19:00:00',
#    'pres': 1015,
#    'solar_rad': 165.955,
#    'ozone': 304,
#    'weather': {'icon': 'c04d', 'code': 804, 'description': 'Overcast clouds'},
#    'wind_gust_spd': 5.63,
#    'timestamp_local': '2022-08-08T12:00:00',
#    'snow_depth': 0,
#    'clouds': 100,
#    'ts': 1659985200,
#    'wind_spd': 4.21,
#    'pop': 0,
#    'wind_cdir_full': 'southwest',
#    'slp': 1015.5,
#    'dni': 889.41,
#    'dewpt': 13.7,
#    'snow': 0,
#    'uv': 2.3,
#    'wind_dir': 215,
#    'clouds_hi': 0,
#    'precip': 0,
#    'vis': 12.2,
#    'dhi': 115.83,
#    'app_temp': 14.4,
#    'datetime': '2022-08-08:19',
#    'temp': 14.4,
#    'ghi': 838.08,
#    'clouds_mid': 0,
#    'clouds_low': 100},
#   {'wind_cdir': 'SW',
#    'rh': 96,
#    'pod': 'd',
#    'timestamp_utc': '2022-08-08T20:00:00',
#    'pres': 1015,
#    'solar_rad': 170.293,
#    'ozone': 303.8,
#    'weather': {'icon': 'c04d', 'code': 804, 'description': 'Overcast clouds'},
#    'wind_gust_spd': 4.7,
#    'timestamp_local': '2022-08-08T13:00:00',
#    'snow_depth': 0,
#    'clouds': 100,
#    'ts': 1659988800,
#    'wind_spd': 3.75,
#    'pop': 0,
#    'wind_cdir_full': 'southwest',
#    'slp': 1015.5,
#    'dni': 900.98,
#    'dewpt': 14.3,
#    'snow': 0,
#    'uv': 2.5,
#    'wind_dir': 221,
#    'clouds_hi': 0,
#    'precip': 0,
#    'vis': 12.2,
#    'dhi': 118.31,
#    'app_temp': 14.9,
#    'datetime': '2022-08-08:20',
#    'temp': 14.9,
#    'ghi': 884.91,
#    'clouds_mid': 0,
#    'clouds_low': 100},
#   {'wind_cdir': 'SW',
#    'rh': 94,
#    'pod': 'd',
#    'timestamp_utc': '2022-08-08T21:00:00',
#    'pres': 1015,
#    'solar_rad': 169.82,
#    'ozone': 304.5,
#    'weather': {'icon': 'c04d', 'code': 804, 'description': 'Overcast clouds'},
#    'wind_gust_spd': 6.12,
#    'timestamp_local': '2022-08-08T14:00:00',
#    'snow_depth': 0,
#    'clouds': 100,
#    'ts': 1659992400,
#    'wind_spd': 4.68,
#    'pop': 0,
#    'wind_cdir_full': 'southwest',
#    'slp': 1015.5,
#    'dni': 899.21,
#    'dewpt': 14,
#    'snow': 0,
#    'uv': 2.5,
#    'wind_dir': 216,
#    'clouds_hi': 0,
#    'precip': 0,
#    'vis': 12.2,
#    'dhi': 117.93,
#    'app_temp': 15,
#    'datetime': '2022-08-08:21',
#    'temp': 15,
#    'ghi': 877.53,
#    'clouds_mid': 0,
#    'clouds_low': 100},
#   {'wind_cdir': 'SW',
#    'rh': 97,
#    'pod': 'd',
#    'timestamp_utc': '2022-08-08T22:00:00',
#    'pres': 1014.5,
#    'solar_rad': 162.925,
#    'ozone': 305.3,
#    'weather': {'icon': 'c04d', 'code': 804, 'description': 'Overcast clouds'},
#    'wind_gust_spd': 5.68,
#    'timestamp_local': '2022-08-08T15:00:00',
#    'snow_depth': 0,
#    'clouds': 100,
#    'ts': 1659996000,
#    'wind_spd': 3.85,
#    'pop': 0,
#    'wind_cdir_full': 'southwest',
#    'slp': 1015.5,
#    'dni': 883.83,
#    'dewpt': 14.1,
#    'snow': 0,
#    'uv': 2.2,
#    'wind_dir': 230,
#    'clouds_hi': 0,
#    'precip': 0,
#    'vis': 1,
#    'dhi': 114.66,
#    'app_temp': 14.6,
#    'datetime': '2022-08-08:22',
#    'temp': 14.6,
#    'ghi': 816.54,
#    'clouds_mid': 0,
#    'clouds_low': 100},
#   {'wind_cdir': 'SW',
#    'rh': 96,
#    'pod': 'd',
#    'timestamp_utc': '2022-08-08T23:00:00',
#    'pres': 1014.5,
#    'solar_rad': 149.406,
#    'ozone': 305.8,
#    'weather': {'icon': 'c04d', 'code': 804, 'description': 'Overcast clouds'},
#    'wind_gust_spd': 4.48,
#    'timestamp_local': '2022-08-08T16:00:00',
#    'snow_depth': 0,
#    'clouds': 100,
#    'ts': 1659999600,
#    'wind_spd': 3.13,
#    'pop': 0,
#    'wind_cdir_full': 'southwest',
#    'slp': 1015,
#    'dni': 852.74,
#    'dewpt': 14.5,
#    'snow': 0,
#    'uv': 1.7,
#    'wind_dir': 232,
#    'clouds_hi': 0,
#    'precip': 0,
#    'vis': 12.2,
#    'dhi': 108.36,
#    'app_temp': 15.1,
#    'datetime': '2022-08-08:23',
#    'temp': 15.1,
#    'ghi': 707.21,
#    'clouds_mid': 0,
#    'clouds_low': 100},
#   {'wind_cdir': 'SW',
#    'rh': 94,
#    'pod': 'd',
#    'timestamp_utc': '2022-08-09T00:00:00',
#    'pres': 1014,
#    'solar_rad': 131.432,
#    'ozone': 305.8,
#    'weather': {'icon': 'c04d', 'code': 804, 'description': 'Overcast clouds'},
#    'wind_gust_spd': 4.68,
#    'timestamp_local': '2022-08-08T17:00:00',
#    'snow_depth': 0,
#    'clouds': 100,
#    'ts': 1660003200,
#    'wind_spd': 3.58,
#    'pop': 0,
#    'wind_cdir_full': 'southwest',
#    'slp': 1014.5,
#    'dni': 801.16,
#    'dewpt': 14.1,
#    'snow': 0,
#    'uv': 1.2,
#    'wind_dir': 223,
#    'clouds_hi': 0,
#    'precip': 0,
#    'vis': 12.2,
#    'dhi': 98.66,
#    'app_temp': 15,
#    'datetime': '2022-08-09:00',
#    'temp': 15,
#    'ghi': 559.43,
#    'clouds_mid': 0,
#    'clouds_low': 100},
#   {'wind_cdir': 'SW',
#    'rh': 97,
#    'pod': 'd',
#    'timestamp_utc': '2022-08-09T01:00:00',
#    'pres': 1014,
#    'solar_rad': 107.55,
#    'ozone': 304.8,
#    'weather': {'icon': 'c04d', 'code': 804, 'description': 'Overcast clouds'},
#    'wind_gust_spd': 4.92,
#    'timestamp_local': '2022-08-08T18:00:00',
#    'snow_depth': 0,
#    'clouds': 100,
#    'ts': 1660006800,
#    'wind_spd': 3.65,
#    'pop': 0,
#    'wind_cdir_full': 'southwest',
#    'slp': 1014.5,
#    'dni': 717.65,
#    'dewpt': 13.8,
#    'snow': 0,
#    'uv': 0.8,
#    'wind_dir': 221,
#    'clouds_hi': 0,
#    'precip': 0,
#    'vis': 0.8,
#    'dhi': 84.74,
#    'app_temp': 14.2,
#    'datetime': '2022-08-09:01',
#    'temp': 14.2,
#    'ghi': 386.58,
#    'clouds_mid': 0,
#    'clouds_low': 100},
#   {'wind_cdir': 'SW',
#    'rh': 97,
#    'pod': 'd',
#    'timestamp_utc': '2022-08-09T02:00:00',
#    'pres': 1014,
#    'solar_rad': 76.9198,
#    'ozone': 303.8,
#    'weather': {'icon': 'c04d', 'code': 804, 'description': 'Overcast clouds'},
#    'wind_gust_spd': 4.8,
#    'timestamp_local': '2022-08-08T19:00:00',
#    'snow_depth': 0,
#    'clouds': 100,
#    'ts': 1660010400,
#    'wind_spd': 3.44,
#    'pop': 0,
#    'wind_cdir_full': 'southwest',
#    'slp': 1014.5,
#    'dni': 575.57,
#    'dewpt': 13.5,
#    'snow': 0,
#    'uv': 0.5,
#    'wind_dir': 227,
#    'clouds_hi': 0,
#    'precip': 0,
#    'vis': 0.3,
#    'dhi': 64.85,
#    'app_temp': 13.9,
#    'datetime': '2022-08-09:02',
#    'temp': 13.9,
#    'ghi': 207.14,
#    'clouds_mid': 0,
#    'clouds_low': 100},
#   {'wind_cdir': 'SW',
#    'rh': 98,
#    'pod': 'd',
#    'timestamp_utc': '2022-08-09T03:00:00',
#    'pres': 1014,
#    'solar_rad': 36.0337,
#    'ozone': 303.8,
#    'weather': {'icon': 'c04d', 'code': 804, 'description': 'Overcast clouds'},
#    'wind_gust_spd': 4.95,
#    'timestamp_local': '2022-08-08T20:00:00',
#    'snow_depth': 0,
#    'clouds': 100,
#    'ts': 1660014000,
#    'wind_spd': 3.52,
#    'pop': 0,
#    'wind_cdir_full': 'southwest',
#    'slp': 1015,
#    'dni': 282.44,
#    'dewpt': 13.3,
#    'snow': 0,
#    'uv': 0.5,
#    'wind_dir': 224,
#    'clouds_hi': 0,
#    'precip': 0,
#    'vis': 0.2,
#    'dhi': 33.41,
#    'app_temp': 13.7,
#    'datetime': '2022-08-09:03',
#    'temp': 13.7,
#    'ghi': 48.62,
#    'clouds_mid': 0,
#    'clouds_low': 100},
#   {'wind_cdir': 'SW',
#    'rh': 100,
#    'pod': 'n',
#    'timestamp_utc': '2022-08-09T04:00:00',
#    'pres': 1014,
#    'solar_rad': 0,
#    'ozone': 304.5,
#    'weather': {'icon': 'c04n', 'code': 804, 'description': 'Overcast clouds'},
#    'wind_gust_spd': 4.84,
#    'timestamp_local': '2022-08-08T21:00:00',
#    'snow_depth': 0,
#    'clouds': 100,
#    'ts': 1660017600,
#    'wind_spd': 3.38,
#    'pop': 20,
#    'wind_cdir_full': 'southwest',
#    'slp': 1014.5,
#    'dni': 0,
#    'dewpt': 13.5,
#    'snow': 0,
#    'uv': 0,
#    'wind_dir': 222,
#    'clouds_hi': 0,
#    'precip': 0.000999451,
#    'vis': 0.1,
#    'dhi': 0,
#    'app_temp': 13.5,
#    'datetime': '2022-08-09:04',
#    'temp': 13.5,
#    'ghi': 0,
#    'clouds_mid': 0,
#    'clouds_low': 100},
#   {'wind_cdir': 'SW',
#    'rh': 100,
#    'pod': 'n',
#    'timestamp_utc': '2022-08-09T05:00:00',
#    'pres': 1014,
#    'solar_rad': 0,
#    'ozone': 304.8,
#    'weather': {'icon': 'c04n', 'code': 804, 'description': 'Overcast clouds'},
#    'wind_gust_spd': 4.49,
#    'timestamp_local': '2022-08-08T22:00:00',
#    'snow_depth': 0,
#    'clouds': 100,
#    'ts': 1660021200,
#    'wind_spd': 3.24,
#    'pop': 20,
#    'wind_cdir_full': 'southwest',
#    'slp': 1015,
#    'dni': 0,
#    'dewpt': 13.4,
#    'snow': 0,
#    'uv': 0,
#    'wind_dir': 220,
#    'clouds_hi': 0,
#    'precip': 0.0019989,
#    'vis': 0.1,
#    'dhi': 0,
#    'app_temp': 13.4,
#    'datetime': '2022-08-09:05',
#    'temp': 13.4,
#    'ghi': 0,
#    'clouds_mid': 0,
#    'clouds_low': 100},
#   {'wind_cdir': 'SW',
#    'rh': 100,
#    'pod': 'n',
#    'timestamp_utc': '2022-08-09T06:00:00',
#    'pres': 1014,
#    'solar_rad': 0,
#    'ozone': 304.5,
#    'weather': {'icon': 'c04n', 'code': 804, 'description': 'Overcast clouds'},
#    'wind_gust_spd': 4.61,
#    'timestamp_local': '2022-08-08T23:00:00',
#    'snow_depth': 0,
#    'clouds': 100,
#    'ts': 1660024800,
#    'wind_spd': 3.27,
#    'pop': 20,
#    'wind_cdir_full': 'southwest',
#    'slp': 1015,
#    'dni': 0,
#    'dewpt': 13.2,
#    'snow': 0,
#    'uv': 0,
#    'wind_dir': 218,
#    'clouds_hi': 0,
#    'precip': 0.00999451,
#    'vis': 0,
#    'dhi': 0,
#    'app_temp': 13.2,
#    'datetime': '2022-08-09:06',
#    'temp': 13.2,
#    'ghi': 0,
#    'clouds_mid': 0,
#    'clouds_low': 100},
#   {'wind_cdir': 'SSW',
#    'rh': 100,
#    'pod': 'n',
#    'timestamp_utc': '2022-08-09T07:00:00',
#    'pres': 1014.5,
#    'solar_rad': 0,
#    'ozone': 303.8,
#    'weather': {'icon': 'c04n', 'code': 804, 'description': 'Overcast clouds'},
#    'wind_gust_spd': 5.5,
#    'timestamp_local': '2022-08-09T00:00:00',
#    'snow_depth': 0,
#    'clouds': 100,
#    'ts': 1660028400,
#    'wind_spd': 3.95,
#    'pop': 20,
#    'wind_cdir_full': 'south-southwest',
#    'slp': 1015,
#    'dni': 0,
#    'dewpt': 13.1,
#    'snow': 0,
#    'uv': 0,
#    'wind_dir': 207,
#    'clouds_hi': 0,
#    'precip': 0.0169983,
#    'vis': 0.1,
#    'dhi': 0,
#    'app_temp': 13.1,
#    'datetime': '2022-08-09:07',
#    'temp': 13.1,
#    'ghi': 0,
#    'clouds_mid': 0,
#    'clouds_low': 100},
#   {'wind_cdir': 'SSW',
#    'rh': 100,
#    'pod': 'n',
#    'timestamp_utc': '2022-08-09T08:00:00',
#    'pres': 1014.5,
#    'solar_rad': 0,
#    'ozone': 303,
#    'weather': {'icon': 'c04n', 'code': 804, 'description': 'Overcast clouds'},
#    'wind_gust_spd': 7.22,
#    'timestamp_local': '2022-08-09T01:00:00',
#    'snow_depth': 0,
#    'clouds': 100,
#    'ts': 1660032000,
#    'wind_spd': 4.8,
#    'pop': 20,
#    'wind_cdir_full': 'south-southwest',
#    'slp': 1014.5,
#    'dni': 0,
#    'dewpt': 13.1,
#    'snow': 0,
#    'uv': 0,
#    'wind_dir': 213,
#    'clouds_hi': 0,
#    'precip': 0.00799561,
#    'vis': 0.1,
#    'dhi': 0,
#    'app_temp': 13.1,
#    'datetime': '2022-08-09:08',
#    'temp': 13.1,
#    'ghi': 0,
#    'clouds_mid': 0,
#    'clouds_low': 100},
#   {'wind_cdir': 'WSW',
#    'rh': 100,
#    'pod': 'n',
#    'timestamp_utc': '2022-08-09T09:00:00',
#    'pres': 1013.5,
#    'solar_rad': 0,
#    'ozone': 302.3,
#    'weather': {'icon': 'c04n', 'code': 804, 'description': 'Overcast clouds'},
#    'wind_gust_spd': 4.75,
#    'timestamp_local': '2022-08-09T02:00:00',
#    'snow_depth': 0,
#    'clouds': 100,
#    'ts': 1660035600,
#    'wind_spd': 3.2,
#    'pop': 20,
#    'wind_cdir_full': 'west-southwest',
#    'slp': 1014.5,
#    'dni': 0,
#    'dewpt': 13.3,
#    'snow': 0,
#    'uv': 0,
#    'wind_dir': 254,
#    'clouds_hi': 0,
#    'precip': 0.0019989,
#    'vis': 0.1,
#    'dhi': 0,
#    'app_temp': 13.3,
#    'datetime': '2022-08-09:09',
#    'temp': 13.3,
#    'ghi': 0,
#    'clouds_mid': 100,
#    'clouds_low': 100},
#   {'wind_cdir': 'WSW',
#    'rh': 99,
#    'pod': 'n',
#    'timestamp_utc': '2022-08-09T10:00:00',
#    'pres': 1013.5,
#    'solar_rad': 0,
#    'ozone': 300.8,
#    'weather': {'icon': 'c04n', 'code': 804, 'description': 'Overcast clouds'},
#    'wind_gust_spd': 2.36,
#    'timestamp_local': '2022-08-09T03:00:00',
#    'snow_depth': 0,
#    'clouds': 100,
#    'ts': 1660039200,
#    'wind_spd': 1.74,
#    'pop': 0,
#    'wind_cdir_full': 'west-southwest',
#    'slp': 1014,
#    'dni': 0,
#    'dewpt': 13.1,
#    'snow': 0,
#    'uv': 0,
#    'wind_dir': 244,
#    'clouds_hi': 0,
#    'precip': 0,
#    'vis': 0.1,
#    'dhi': 0,
#    'app_temp': 13.2,
#    'datetime': '2022-08-09:10',
#    'temp': 13.2,
#    'ghi': 0,
#    'clouds_mid': 0,
#    'clouds_low': 100},
#   {'wind_cdir': 'SSW',
#    'rh': 100,
#    'pod': 'n',
#    'timestamp_utc': '2022-08-09T11:00:00',
#    'pres': 1014,
#    'solar_rad': 0,
#    'ozone': 301.5,
#    'weather': {'icon': 'c04n', 'code': 804, 'description': 'Overcast clouds'},
#    'wind_gust_spd': 2.55,
#    'timestamp_local': '2022-08-09T04:00:00',
#    'snow_depth': 0,
#    'clouds': 100,
#    'ts': 1660042800,
#    'wind_spd': 1.76,
#    'pop': 0,
#    'wind_cdir_full': 'south-southwest',
#    'slp': 1014.5,
#    'dni': 0,
#    'dewpt': 13.1,
#    'snow': 0,
#    'uv': 0,
#    'wind_dir': 201,
#    'clouds_hi': 0,
#    'precip': 0,
#    'vis': 0.1,
#    'dhi': 0,
#    'app_temp': 13.1,
#    'datetime': '2022-08-09:11',
#    'temp': 13.1,
#    'ghi': 0,
#    'clouds_mid': 55,
#    'clouds_low': 100},
#   {'wind_cdir': 'SSW',
#    'rh': 98,
#    'pod': 'n',
#    'timestamp_utc': '2022-08-09T12:00:00',
#    'pres': 1014,
#    'solar_rad': 0,
#    'ozone': 300.8,
#    'weather': {'icon': 'c04n', 'code': 804, 'description': 'Overcast clouds'},
#    'wind_gust_spd': 3.55,
#    'timestamp_local': '2022-08-09T05:00:00',
#    'snow_depth': 0,
#    'clouds': 100,
#    'ts': 1660046400,
#    'wind_spd': 2.44,
#    'pop': 0,
#    'wind_cdir_full': 'south-southwest',
#    'slp': 1014.5,
#    'dni': 0,
#    'dewpt': 13.1,
#    'snow': 0,
#    'uv': 0,
#    'wind_dir': 213,
#    'clouds_hi': 0,
#    'precip': 0,
#    'vis': 0.3,
#    'dhi': 0,
#    'app_temp': 13.4,
#    'datetime': '2022-08-09:12',
#    'temp': 13.4,
#    'ghi': 0,
#    'clouds_mid': 1,
#    'clouds_low': 100},
#   {'wind_cdir': 'SSW',
#    'rh': 99,
#    'pod': 'n',
#    'timestamp_utc': '2022-08-09T13:00:00',
#    'pres': 1014,
#    'solar_rad': 0,
#    'ozone': 301,
#    'weather': {'icon': 'c04n', 'code': 804, 'description': 'Overcast clouds'},
#    'wind_gust_spd': 3.4,
#    'timestamp_local': '2022-08-09T06:00:00',
#    'snow_depth': 0,
#    'clouds': 100,
#    'ts': 1660050000,
#    'wind_spd': 2.39,
#    'pop': 0,
#    'wind_cdir_full': 'south-southwest',
#    'slp': 1014.5,
#    'dni': 0,
#    'dewpt': 13.1,
#    'snow': 0,
#    'uv': 0,
#    'wind_dir': 201,
#    'clouds_hi': 0,
#    'precip': 0,
#    'vis': 0.2,
#    'dhi': 0,
#    'app_temp': 13.3,
#    'datetime': '2022-08-09:13',
#    'temp': 13.3,
#    'ghi': 0,
#    'clouds_mid': 86,
#    'clouds_low': 100},
#   {'wind_cdir': 'S',
#    'rh': 98,
#    'pod': 'd',
#    'timestamp_utc': '2022-08-09T14:00:00',
#    'pres': 1013.5,
#    'solar_rad': 48.2258,
#    'ozone': 301,
#    'weather': {'icon': 'c04d', 'code': 804, 'description': 'Overcast clouds'},
#    'wind_gust_spd': 1.16,
#    'timestamp_local': '2022-08-09T07:00:00',
#    'snow_depth': 0,
#    'clouds': 100,
#    'ts': 1660053600,
#    'wind_spd': 0.74,
#    'pop': 0,
#    'wind_cdir_full': 'south',
#    'slp': 1014,
#    'dni': 385.15,
#    'dewpt': 13.1,
#    'snow': 0,
#    'uv': 0.5,
#    'wind_dir': 184,
#    'clouds_hi': 0,
#    'precip': 0,
#    'vis': 0.4,
#    'dhi': 43.39,
#    'app_temp': 13.4,
#    'datetime': '2022-08-09:14',
#    'temp': 13.4,
#    'ghi': 84.97,
#    'clouds_mid': 34,
#    'clouds_low': 100},
#   {'wind_cdir': 'S',
#    'rh': 96,
#    'pod': 'd',
#    'timestamp_utc': '2022-08-09T15:00:00',
#    'pres': 1013.5,
#    'solar_rad': 85.6881,
#    'ozone': 301.3,
#    'weather': {'icon': 'c04d', 'code': 804, 'description': 'Overcast clouds'},
#    'wind_gust_spd': 1.88,
#    'timestamp_local': '2022-08-09T08:00:00',
#    'snow_depth': 0,
#    'clouds': 100,
#    'ts': 1660057200,
#    'wind_spd': 1.17,
#    'pop': 0,
#    'wind_cdir_full': 'south',
#    'slp': 1014,
#    'dni': 620.53,
#    'dewpt': 13.2,
#    'snow': 0,
#    'uv': 0.6,
#    'wind_dir': 179,
#    'clouds_hi': 0,
#    'precip': 0,
#    'vis': 12.2,
#    'dhi': 70.71,
#    'app_temp': 13.8,
#    'datetime': '2022-08-09:15',
#    'temp': 13.8,
#    'ghi': 252.62,
#    'clouds_mid': 11,
#    'clouds_low': 100},
#   {'wind_cdir': 'SW',
#    'rh': 96,
#    'pod': 'd',
#    'timestamp_utc': '2022-08-09T16:00:00',
#    'pres': 1013,
#    'solar_rad': 114.506,
#    'ozone': 302,
#    'weather': {'icon': 'c04d', 'code': 804, 'description': 'Overcast clouds'},
#    'wind_gust_spd': 1.01,
#    'timestamp_local': '2022-08-09T09:00:00',
#    'snow_depth': 0,
#    'clouds': 100,
#    'ts': 1660060800,
#    'wind_spd': 0.95,
#    'pop': 0,
#    'wind_cdir_full': 'southwest',
#    'slp': 1014,
#    'dni': 742.98,
#    'dewpt': 13.6,
#    'snow': 0,
#    'uv': 0.8,
#    'wind_dir': 221,
#    'clouds_hi': 88,
#    'precip': 0,
#    'vis': 12.2,
#    'dhi': 88.76,
#    'app_temp': 14.2,
#    'datetime': '2022-08-09:16',
#    'temp': 14.2,
#    'ghi': 432.11,
#    'clouds_mid': 100,
#    'clouds_low': 100},
#   {'wind_cdir': 'SSW',
#    'rh': 95,
#    'pod': 'd',
#    'timestamp_utc': '2022-08-09T17:00:00',
#    'pres': 1013,
#    'solar_rad': 137.032,
#    'ozone': 301.8,
#    'weather': {'icon': 'c04d', 'code': 804, 'description': 'Overcast clouds'},
#    'wind_gust_spd': 1.04,
#    'timestamp_local': '2022-08-09T10:00:00',
#    'snow_depth': 0,
#    'clouds': 100,
#    'ts': 1660064400,
#    'wind_spd': 0.97,
#    'pop': 0,
#    'wind_cdir_full': 'south-southwest',
#    'slp': 1014,
#    'dni': 816.63,
#    'dewpt': 13.9,
#    'snow': 0,
#    'uv': 1.3,
#    'wind_dir': 212,
#    'clouds_hi': 0,
#    'precip': 0,
#    'vis': 12.2,
#    'dhi': 101.47,
#    'app_temp': 14.7,
#    'datetime': '2022-08-09:17',
#    'temp': 14.7,
#    'ghi': 599.69,
#    'clouds_mid': 86,
#    'clouds_low': 100},
#   {'wind_cdir': 'WNW',
#    'rh': 93,
#    'pod': 'd',
#    'timestamp_utc': '2022-08-09T18:00:00',
#    'pres': 1012.5,
#    'solar_rad': 436.396,
#    'ozone': 302.8,
#    'weather': {'icon': 'c04d', 'code': 804, 'description': 'Overcast clouds'},
#    'wind_gust_spd': 2.91,
#    'timestamp_local': '2022-08-09T11:00:00',
#    'snow_depth': 0,
#    'clouds': 77,
#    'ts': 1660068000,
#    'wind_spd': 2.42,
#    'pop': 0,
#    'wind_cdir_full': 'west-northwest',
#    'slp': 1013.5,
#    'dni': 862.33,
#    'dewpt': 14,
#    'snow': 0,
#    'uv': 2.7,
#    'wind_dir': 288,
#    'clouds_hi': 0,
#    'precip': 0,
#    'vis': 12.696,
#    'dhi': 110.24,
#    'app_temp': 15.1,
#    'datetime': '2022-08-09:18',
#    'temp': 15.1,
#    'ghi': 738.37,
#    'clouds_mid': 77,
#    'clouds_low': 62},
#   {'wind_cdir': 'NW',
#    'rh': 79,
#    'pod': 'd',
#    'timestamp_utc': '2022-08-09T19:00:00',
#    'pres': 1012.5,
#    'solar_rad': 686.268,
#    'ozone': 303.5,
#    'weather': {'icon': 'c03d', 'code': 803, 'description': 'Broken clouds'},
#    'wind_gust_spd': 1.7,
#    'timestamp_local': '2022-08-09T12:00:00',
#    'snow_depth': 0,
#    'clouds': 58,
#    'ts': 1660071600,
#    'wind_spd': 1.64,
#    'pop': 0,
#    'wind_cdir_full': 'northwest',
#    'slp': 1013,
#    'dni': 888.94,
#    'dewpt': 13.6,
#    'snow': 0,
#    'uv': 4.4,
#    'wind_dir': 315,
#    'clouds_hi': 0,
#    'precip': 0,
#    'vis': 24.096,
#    'dhi': 115.71,
#    'app_temp': 17.2,
#    'datetime': '2022-08-09:19',
#    'temp': 17.2,
#    'ghi': 835.38,
#    'clouds_mid': 15,
#    'clouds_low': 58},
#   {'wind_cdir': 'WNW',
#    'rh': 79,
#    'pod': 'd',
#    'timestamp_utc': '2022-08-09T20:00:00',
#    'pres': 1012,
#    'solar_rad': 731.728,
#    'ozone': 303.5,
#    'weather': {'icon': 'c03d', 'code': 803, 'description': 'Broken clouds'},
#    'wind_gust_spd': 2.6,
#    'timestamp_local': '2022-08-09T13:00:00',
#    'snow_depth': 0,
#    'clouds': 57,
#    'ts': 1660075200,
#    'wind_spd': 2.33,
#    'pop': 0,
#    'wind_cdir_full': 'west-northwest',
#    'slp': 1012.5,
#    'dni': 900.54,
#    'dewpt': 13.6,
#    'snow': 0,
#    'uv': 4.9,
#    'wind_dir': 295,
#    'clouds_hi': 0,
#    'precip': 0,
#    'vis': 24.096,
#    'dhi': 118.19,
#    'app_temp': 17.3,
#    'datetime': '2022-08-09:20',
#    'temp': 17.3,
#    'ghi': 882.15,
#    'clouds_mid': 28,
#    'clouds_low': 57},
#   {'wind_cdir': 'WNW',
#    'rh': 78,
#    'pod': 'd',
#    'timestamp_utc': '2022-08-09T21:00:00',
#    'pres': 1012,
#    'solar_rad': 717.392,
#    'ozone': 303.5,
#    'weather': {'icon': 'c03d', 'code': 803, 'description': 'Broken clouds'},
#    'wind_gust_spd': 3.1,
#    'timestamp_local': '2022-08-09T14:00:00',
#    'snow_depth': 0,
#    'clouds': 58,
#    'ts': 1660078800,
#    'wind_spd': 2.64,
#    'pop': 10,
#    'wind_cdir_full': 'west-northwest',
#    'slp': 1012.5,
#    'dni': 898.72,
#    'dewpt': 14,
#    'snow': 0,
#    'uv': 4.8,
#    'wind_dir': 298,
#    'clouds_hi': 0,
#    'precip': 0.0625,
#    'vis': 24.096,
#    'dhi': 117.8,
#    'app_temp': 17.9,
#    'datetime': '2022-08-09:21',
#    'temp': 17.9,
#    'ghi': 874.61,
#    'clouds_mid': 13,
#    'clouds_low': 58},
#   {'wind_cdir': 'WNW',
#    'rh': 78,
#    'pod': 'd',
#    'timestamp_utc': '2022-08-09T22:00:00',
#    'pres': 1012,
#    'solar_rad': 673.371,
#    'ozone': 304.3,
#    'weather': {'icon': 'c03d', 'code': 803, 'description': 'Broken clouds'},
#    'wind_gust_spd': 2.5,
#    'timestamp_local': '2022-08-09T15:00:00',
#    'snow_depth': 0,
#    'clouds': 57,
#    'ts': 1660082400,
#    'wind_spd': 2.13,
#    'pop': 10,
#    'wind_cdir_full': 'west-northwest',
#    'slp': 1012.5,
#    'dni': 883.23,
#    'dewpt': 14.2,
#    'snow': 0,
#    'uv': 4.2,
#    'wind_dir': 301,
#    'clouds_hi': 0,
#    'precip': 0.0625,
#    'vis': 24.096,
#    'dhi': 114.51,
#    'app_temp': 18.1,
#    'datetime': '2022-08-09:22',
#    'temp': 18.1,
#    'ghi': 813.41,
#    'clouds_mid': 9,
#    'clouds_low': 57},
#   {'wind_cdir': 'NW',
#    'rh': 79,
#    'pod': 'd',
#    'timestamp_utc': '2022-08-09T23:00:00',
#    'pres': 1011,
#    'solar_rad': 558.681,
#    'ozone': 305.5,
#    'weather': {'icon': 'c03d', 'code': 803, 'description': 'Broken clouds'},
#    'wind_gust_spd': 2.2,
#    'timestamp_local': '2022-08-09T16:00:00',
#    'snow_depth': 0,
#    'clouds': 61,
#    'ts': 1660086000,
#    'wind_spd': 1.95,
#    'pop': 0,
#    'wind_cdir_full': 'northwest',
#    'slp': 1011.5,
#    'dni': 851.9,
#    'dewpt': 14,
#    'snow': 0,
#    'uv': 3.1,
#    'wind_dir': 305,
#    'clouds_hi': 0,
#    'precip': 0,
#    'vis': 24.096,
#    'dhi': 108.17,
#    'app_temp': 17.7,
#    'datetime': '2022-08-09:23',
#    'temp': 17.7,
#    'ghi': 703.83,
#    'clouds_mid': 9,
#    'clouds_low': 61},
#   {'wind_cdir': 'NW',
#    'rh': 81,
#    'pod': 'd',
#    'timestamp_utc': '2022-08-10T00:00:00',
#    'pres': 1011,
#    'solar_rad': 436.347,
#    'ozone': 306,
#    'weather': {'icon': 'c03d', 'code': 803, 'description': 'Broken clouds'},
#    'wind_gust_spd': 2.2,
#    'timestamp_local': '2022-08-09T17:00:00',
#    'snow_depth': 0,
#    'clouds': 62,
#    'ts': 1660089600,
#    'wind_spd': 1.86,
#    'pop': 10,
#    'wind_cdir_full': 'northwest',
#    'slp': 1011.5,
#    'dni': 799.9,
#    'dewpt': 13.6,
#    'snow': 0,
#    'uv': 2.1,
#    'wind_dir': 308,
#    'clouds_hi': 0,
#    'precip': 0.0625,
#    'vis': 24.096,
#    'dhi': 98.42,
#    'app_temp': 16.9,
#    'datetime': '2022-08-10:00',
#    'temp': 16.9,
#    'ghi': 555.79,
#    'clouds_mid': 14,
#    'clouds_low': 62},
#   {'wind_cdir': 'W',
#    'rh': 83,
#    'pod': 'd',
#    'timestamp_utc': '2022-08-10T01:00:00',
#    'pres': 1011,
#    'solar_rad': 265.798,
#    'ozone': 305.8,
#    'weather': {'icon': 'c03d', 'code': 803, 'description': 'Broken clouds'},
#    'wind_gust_spd': 2.9,
#    'timestamp_local': '2022-08-09T18:00:00',
#    'snow_depth': 0,
#    'clouds': 70,
#    'ts': 1660093200,
#    'wind_spd': 2.04,
#    'pop': 0,
#    'wind_cdir_full': 'west',
#    'slp': 1011.5,
#    'dni': 715.55,
#    'dewpt': 13.7,
#    'snow': 0,
#    'uv': 1.2,
#    'wind_dir': 265,
#    'clouds_hi': 0,
#    'precip': 0,
#    'vis': 24.096,
#    'dhi': 84.4,
#    'app_temp': 16.6,
#    'datetime': '2022-08-10:01',
#    'temp': 16.6,
#    'ghi': 382.75,
#    'clouds_mid': 13,
#    'clouds_low': 70},
#   {'wind_cdir': 'WSW',
#    'rh': 89,
#    'pod': 'd',
#    'timestamp_utc': '2022-08-10T02:00:00',
#    'pres': 1011,
#    'solar_rad': 106.135,
#    'ozone': 306.3,
#    'weather': {'icon': 'c04d', 'code': 804, 'description': 'Overcast clouds'},
#    'wind_gust_spd': 3.4,
#    'timestamp_local': '2022-08-09T19:00:00',
#    'snow_depth': 0,
#    'clouds': 81,
#    'ts': 1660096800,
#    'wind_spd': 2.17,
#    'pop': 10,
#    'wind_cdir_full': 'west-southwest',
#    'slp': 1011.5,
#    'dni': 571.48,
#    'dewpt': 13.9,
#    'snow': 0,
#    'uv': 0.7,
#    'wind_dir': 245,
#    'clouds_hi': 0,
#    'precip': 0.0625,
#    'vis': 24.096,
#    'dhi': 64.34,
#    'app_temp': 15.7,
#    'datetime': '2022-08-10:02',
#    'temp': 15.7,
#    'ghi': 203.31,
#    'clouds_mid': 9,
#    'clouds_low': 81},
#   {'wind_cdir': 'SW',
#    'rh': 94,
#    'pod': 'd',
#    'timestamp_utc': '2022-08-10T03:00:00',
#    'pres': 1011.5,
#    'solar_rad': 43.6664,
#    'ozone': 306.3,
#    'weather': {'icon': 'c04d', 'code': 804, 'description': 'Overcast clouds'},
#    'wind_gust_spd': 3.5,
#    'timestamp_local': '2022-08-09T20:00:00',
#    'snow_depth': 0,
#    'clouds': 93,
#    'ts': 1660100400,
#    'wind_spd': 2.14,
#    'pop': 0,
#    'wind_cdir_full': 'southwest',
#    'slp': 1012,
#    'dni': 271.46,
#    'dewpt': 14.3,
#    'snow': 0,
#    'uv': 0.5,
#    'wind_dir': 225,
#    'clouds_hi': 0,
#    'precip': 0,
#    'vis': 24.096,
#    'dhi': 32.39,
#    'app_temp': 15.3,
#    'datetime': '2022-08-10:03',
#    'temp': 15.3,
#    'ghi': 45.53,
#    'clouds_mid': 2,
#    'clouds_low': 93},
#   {'wind_cdir': 'SSW',
#    'rh': 93,
#    'pod': 'n',
#    'timestamp_utc': '2022-08-10T04:00:00',
#    'pres': 1011.5,
#    'solar_rad': 0,
#    'ozone': 306.5,
#    'weather': {'icon': 'c04n', 'code': 804, 'description': 'Overcast clouds'},
#    'wind_gust_spd': 4.6,
#    'timestamp_local': '2022-08-09T21:00:00',
#    'snow_depth': 0,
#    'clouds': 99,
#    'ts': 1660104000,
#    'wind_spd': 2.62,
#    'pop': 10,
#    'wind_cdir_full': 'south-southwest',
#    'slp': 1012.5,
#    'dni': 0,
#    'dewpt': 14.1,
#    'snow': 0,
#    'uv': 0,
#    'wind_dir': 209,
#    'clouds_hi': 0,
#    'precip': 0.0625,
#    'vis': 24.096,
#    'dhi': 0,
#    'app_temp': 15.2,
#    'datetime': '2022-08-10:04',
#    'temp': 15.2,
#    'ghi': 0,
#    'clouds_mid': 3,
#    'clouds_low': 99},
#   {'wind_cdir': 'SSW',
#    'rh': 95,
#    'pod': 'n',
#    'timestamp_utc': '2022-08-10T05:00:00',
#    'pres': 1012.5,
#    'solar_rad': 0,
#    'ozone': 307.5,
#    'weather': {'icon': 'c04n', 'code': 804, 'description': 'Overcast clouds'},
#    'wind_gust_spd': 6.4,
#    'timestamp_local': '2022-08-09T22:00:00',
#    'snow_depth': 0,
#    'clouds': 100,
#    'ts': 1660107600,
#    'wind_spd': 4.5,
#    'pop': 0,
#    'wind_cdir_full': 'south-southwest',
#    'slp': 1013,
#    'dni': 0,
#    'dewpt': 13.7,
#    'snow': 0,
#    'uv': 0,
#    'wind_dir': 206,
#    'clouds_hi': 0,
#    'precip': 0,
#    'vis': 24.096,
#    'dhi': 0,
#    'app_temp': 14.5,
#    'datetime': '2022-08-10:05',
#    'temp': 14.5,
#    'ghi': 0,
#    'clouds_mid': 1,
#    'clouds_low': 100},
#   {'wind_cdir': 'SSW',
#    'rh': 97,
#    'pod': 'n',
#    'timestamp_utc': '2022-08-10T06:00:00',
#    'pres': 1012.5,
#    'solar_rad': 0,
#    'ozone': 307.5,
#    'weather': {'icon': 'c04n', 'code': 804, 'description': 'Overcast clouds'},
#    'wind_gust_spd': 7.7,
#    'timestamp_local': '2022-08-09T23:00:00',
#    'snow_depth': 0,
#    'clouds': 96,
#    'ts': 1660111200,
#    'wind_spd': 4.91,
#    'pop': 10,
#    'wind_cdir_full': 'south-southwest',
#    'slp': 1013.5,
#    'dni': 0,
#    'dewpt': 13.5,
#    'snow': 0,
#    'uv': 0,
#    'wind_dir': 205,
#    'clouds_hi': 0,
#    'precip': 0.0625,
#    'vis': 24.096,
#    'dhi': 0,
#    'app_temp': 13.9,
#    'datetime': '2022-08-10:06',
#    'temp': 13.9,
#    'ghi': 0,
#    'clouds_mid': 1,
#    'clouds_low': 96},
#   {'wind_cdir': 'S',
#    'rh': 91,
#    'pod': 'n',
#    'timestamp_utc': '2022-08-10T07:00:00',
#    'pres': 1012,
#    'solar_rad': 0,
#    'ozone': 306.8,
#    'weather': {'icon': 'c02n', 'code': 802, 'description': 'Scattered clouds'},
#    'wind_gust_spd': 7.02,
#    'timestamp_local': '2022-08-10T00:00:00',
#    'snow_depth': 0,
#    'clouds': 21,
#    'ts': 1660114800,
#    'wind_spd': 5.04,
#    'pop': 0,
#    'wind_cdir_full': 'south',
#    'slp': 1014,
#    'dni': 0,
#    'dewpt': 13.7,
#    'snow': 0,
#    'uv': 0,
#    'wind_dir': 179,
#    'clouds_hi': 0,
#    'precip': 0,
#    'vis': 24.128,
#    'dhi': 0,
#    'app_temp': 15.1,
#    'datetime': '2022-08-10:07',
#    'temp': 15.1,
#    'ghi': 0,
#    'clouds_mid': 21,
#    'clouds_low': 4},
#   {'wind_cdir': 'S',
#    'rh': 93,
#    'pod': 'n',
#    'timestamp_utc': '2022-08-10T08:00:00',
#    'pres': 1011.5,
#    'solar_rad': 0,
#    'ozone': 307.3,
#    'weather': {'icon': 'c02n', 'code': 801, 'description': 'Few clouds'},
#    'wind_gust_spd': 7.41,
#    'timestamp_local': '2022-08-10T01:00:00',
#    'snow_depth': 0,
#    'clouds': 6,
#    'ts': 1660118400,
#    'wind_spd': 5.59,
#    'pop': 10,
#    'wind_cdir_full': 'south',
#    'slp': 1013.5,
#    'dni': 0,
#    'dewpt': 14.3,
#    'snow': 0,
#    'uv': 0,
#    'wind_dir': 185,
#    'clouds_hi': 0,
#    'precip': 0.0625,
#    'vis': 24.128,
#    'dhi': 0,
#    'app_temp': 15.4,
#    'datetime': '2022-08-10:08',
#    'temp': 15.4,
#    'ghi': 0,
#    'clouds_mid': 6,
#    'clouds_low': 6},
#   {'wind_cdir': 'S',
#    'rh': 94,
#    'pod': 'n',
#    'timestamp_utc': '2022-08-10T09:00:00',
#    'pres': 1012,
#    'solar_rad': 0,
#    'ozone': 307.5,
#    'weather': {'icon': 'c02n', 'code': 801, 'description': 'Few clouds'},
#    'wind_gust_spd': 7.61,
#    'timestamp_local': '2022-08-10T02:00:00',
#    'snow_depth': 0,
#    'clouds': 8,
#    'ts': 1660122000,
#    'wind_spd': 5.66,
#    'pop': 10,
#    'wind_cdir_full': 'south',
#    'slp': 1013.5,
#    'dni': 0,
#    'dewpt': 14.5,
#    'snow': 0,
#    'uv': 0,
#    'wind_dir': 180,
#    'clouds_hi': 0,
#    'precip': 0.0625,
#    'vis': 24.128,
#    'dhi': 0,
#    'app_temp': 15.4,
#    'datetime': '2022-08-10:09',
#    'temp': 15.4,
#    'ghi': 0,
#    'clouds_mid': 1,
#    'clouds_low': 8},
#   {'wind_cdir': 'S',
#    'rh': 93,
#    'pod': 'n',
#    'timestamp_utc': '2022-08-10T10:00:00',
#    'pres': 1012,
#    'solar_rad': 0,
#    'ozone': 308,
#    'weather': {'icon': 'c02n', 'code': 802, 'description': 'Scattered clouds'},
#    'wind_gust_spd': 9.11,
#    'timestamp_local': '2022-08-10T03:00:00',
#    'snow_depth': 0,
#    'clouds': 39,
#    'ts': 1660125600,
#    'wind_spd': 6.52,
#    'pop': 25,
#    'wind_cdir_full': 'south',
#    'slp': 1014,
#    'dni': 0,
#    'dewpt': 14.2,
#    'snow': 0,
#    'uv': 0,
#    'wind_dir': 181,
#    'clouds_hi': 0,
#    'precip': 0.25,
#    'vis': 21.584,
#    'dhi': 0,
#    'app_temp': 15.3,
#    'datetime': '2022-08-10:10',
#    'temp': 15.3,
#    'ghi': 0,
#    'clouds_mid': 0,
#    'clouds_low': 39},
#   {'wind_cdir': 'S',
#    'rh': 91,
#    'pod': 'n',
#    'timestamp_utc': '2022-08-10T11:00:00',
#    'pres': 1012,
#    'solar_rad': 0,
#    'ozone': 308.3,
#    'weather': {'icon': 'c03n', 'code': 803, 'description': 'Broken clouds'},
#    'wind_gust_spd': 10.01,
#    'timestamp_local': '2022-08-10T04:00:00',
#    'snow_depth': 0,
#    'clouds': 63,
#    'ts': 1660129200,
#    'wind_spd': 7.09,
#    'pop': 20,
#    'wind_cdir_full': 'south',
#    'slp': 1014,
#    'dni': 0,
#    'dewpt': 13.8,
#    'snow': 0,
#    'uv': 0,
#    'wind_dir': 184,
#    'clouds_hi': 0,
#    'precip': 0.1875,
#    'vis': 17.68,
#    'dhi': 0,
#    'app_temp': 15.2,
#    'datetime': '2022-08-10:11',
#    'temp': 15.2,
#    'ghi': 0,
#    'clouds_mid': 0,
#    'clouds_low': 63},
#   {'wind_cdir': 'S',
#    'rh': 89,
#    'pod': 'n',
#    'timestamp_utc': '2022-08-10T12:00:00',
#    'pres': 1012.5,
#    'solar_rad': 0,
#    'ozone': 308.5,
#    'weather': {'icon': 'c04n', 'code': 804, 'description': 'Overcast clouds'},
#    'wind_gust_spd': 10.3,
#    'timestamp_local': '2022-08-10T05:00:00',
#    'snow_depth': 0,
#    'clouds': 100,
#    'ts': 1660132800,
#    'wind_spd': 7.5,
#    'pop': 15,
#    'wind_cdir_full': 'south',
#    'slp': 1014.5,
#    'dni': 0,
#    'dewpt': 13.7,
#    'snow': 0,
#    'uv': 0,
#    'wind_dir': 186,
#    'clouds_hi': 0,
#    'precip': 0.125,
#    'vis': 24.128,
#    'dhi': 0,
#    'app_temp': 15.5,
#    'datetime': '2022-08-10:12',
#    'temp': 15.5,
#    'ghi': 0,
#    'clouds_mid': 0,
#    'clouds_low': 100},
#   {'wind_cdir': 'S',
#    'rh': 91,
#    'pod': 'n',
#    'timestamp_utc': '2022-08-10T13:00:00',
#    'pres': 1013,
#    'solar_rad': 0,
#    'ozone': 310.3,
#    'weather': {'icon': 'c04n', 'code': 804, 'description': 'Overcast clouds'},
#    'wind_gust_spd': 9.71,
#    'timestamp_local': '2022-08-10T06:00:00',
#    'snow_depth': 0,
#    'clouds': 100,
#    'ts': 1660136400,
#    'wind_spd': 7.23,
#    'pop': 15,
#    'wind_cdir_full': 'south',
#    'slp': 1014.5,
#    'dni': 0,
#    'dewpt': 13.9,
#    'snow': 0,
#    'uv': 0,
#    'wind_dir': 181,
#    'clouds_hi': 0,
#    'precip': 0.125,
#    'vis': 23.152,
#    'dhi': 0,
#    'app_temp': 15.3,
#    'datetime': '2022-08-10:13',
#    'temp': 15.3,
#    'ghi': 0,
#    'clouds_mid': 0,
#    'clouds_low': 100},
#   {'wind_cdir': 'S',
#    'rh': 90,
#    'pod': 'd',
#    'timestamp_utc': '2022-08-10T14:00:00',
#    'pres': 1013.5,
#    'solar_rad': 47.323,
#    'ozone': 312.8,
#    'weather': {'icon': 'c04d', 'code': 804, 'description': 'Overcast clouds'},
#    'wind_gust_spd': 9.54,
#    'timestamp_local': '2022-08-10T07:00:00',
#    'snow_depth': 0,
#    'clouds': 100,
#    'ts': 1660140000,
#    'wind_spd': 6.65,
#    'pop': 10,
#    'wind_cdir_full': 'south',
#    'slp': 1015.5,
#    'dni': 378.78,
#    'dewpt': 13.6,
#    'snow': 0,
#    'uv': 0.5,
#    'wind_dir': 177,
#    'clouds_hi': 0,
#    'precip': 0.0625,
#    'vis': 24.128,
#    'dhi': 42.75,
#    'app_temp': 15.3,
#    'datetime': '2022-08-10:14',
#    'temp': 15.3,
#    'ghi': 82.24,
#    'clouds_mid': 0,
#    'clouds_low': 100},
#   {'wind_cdir': 'S',
#    'rh': 89,
#    'pod': 'd',
#    'timestamp_utc': '2022-08-10T15:00:00',
#    'pres': 1014,
#    'solar_rad': 109.368,
#    'ozone': 314,
#    'weather': {'icon': 'c04d', 'code': 804, 'description': 'Overcast clouds'},
#    'wind_gust_spd': 9.52,
#    'timestamp_local': '2022-08-10T08:00:00',
#    'snow_depth': 0,
#    'clouds': 97,
#    'ts': 1660143600,
#    'wind_spd': 5.9,
#    'pop': 0,
#    'wind_cdir_full': 'south',
#    'slp': 1016,
#    'dni': 617.94,
#    'dewpt': 13.5,
#    'snow': 0,
#    'uv': 0.6,
#    'wind_dir': 174,
#    'clouds_hi': 0,
#    'precip': 0,
#    'vis': 24.128,
#    'dhi': 70.36,
#    'app_temp': 15.3,
#    'datetime': '2022-08-10:15',
#    'temp': 15.3,
#    'ghi': 249.62,
#    'clouds_mid': 0,
#    'clouds_low': 97},
#   {'wind_cdir': 'S',
#    'rh': 88,
#    'pod': 'd',
#    'timestamp_utc': '2022-08-10T16:00:00',
#    'pres': 1014.5,
#    'solar_rad': 241.991,
#    'ozone': 314.5,
#    'weather': {'icon': 'c04d', 'code': 804, 'description': 'Overcast clouds'},
#    'wind_gust_spd': 8.71,
#    'timestamp_local': '2022-08-10T09:00:00',
#    'snow_depth': 0,
#    'clouds': 79,
#    'ts': 1660147200,
#    'wind_spd': 5.54,
#    'pop': 0,
#    'wind_cdir_full': 'south',
#    'slp': 1016.5,
#    'dni': 741.6,
#    'dewpt': 13.5,
#    'snow': 0,
#    'uv': 1.2,
#    'wind_dir': 175,
#    'clouds_hi': 0,
#    'precip': 0,
#    'vis': 24.128,
#    'dhi': 88.52,
#    'app_temp': 15.5,
#    'datetime': '2022-08-10:16',
#    'temp': 15.5,
#    'ghi': 429.17,
#    'clouds_mid': 0,
#    'clouds_low': 79},
#   {'wind_cdir': 'S',
#    'rh': 87,
#    'pod': 'd',
#    'timestamp_utc': '2022-08-10T17:00:00',
#    'pres': 1014.5,
#    'solar_rad': 525.436,
#    'ozone': 316.5,
#    'weather': {'icon': 'c03d', 'code': 803, 'description': 'Broken clouds'},
#    'wind_gust_spd': 8.5,
#    'timestamp_local': '2022-08-10T10:00:00',
#    'snow_depth': 0,
#    'clouds': 49,
#    'ts': 1660150800,
#    'wind_spd': 5.49,
#    'pop': 0,
#    'wind_cdir_full': 'south',
#    'slp': 1016.5,
#    'dni': 815.78,
#    'dewpt': 13.7,
#    'snow': 0,
#    'uv': 2.7,
#    'wind_dir': 181,
#    'clouds_hi': 0,
#    'precip': 0,
#    'vis': 24.128,
#    'dhi': 101.3,
#    'app_temp': 15.8,
#    'datetime': '2022-08-10:17',
#    'temp': 15.8,
#    'ghi': 596.85,
#    'clouds_mid': 0,
#    'clouds_low': 49},
#   {'wind_cdir': 'SSW',
#    'rh': 86,
#    'pod': 'd',
#    'timestamp_utc': '2022-08-10T18:00:00',
#    'pres': 1015,
#    'solar_rad': 195.348,
#    'ozone': 316,
#    'weather': {'icon': 'c04d', 'code': 804, 'description': 'Overcast clouds'},
#    'wind_gust_spd': 9.09,
#    'timestamp_local': '2022-08-10T11:00:00',
#    'snow_depth': 0,
#    'clouds': 93,
#    'ts': 1660154400,
#    'wind_spd': 6.59,
#    'pop': 0,
#    'wind_cdir_full': 'south-southwest',
#    'slp': 1017,
#    'dni': 861.73,
#    'dewpt': 13.6,
#    'snow': 0,
#    'uv': 2.1,
#    'wind_dir': 196,
#    'clouds_hi': 0,
#    'precip': 0,
#    'vis': 24.128,
#    'dhi': 110.1,
#    'app_temp': 15.9,
#    'datetime': '2022-08-10:18',
#    'temp': 15.9,
#    'ghi': 735.61,
#    'clouds_mid': 0,
#    'clouds_low': 93},
#   {'wind_cdir': 'SSW',
#    'rh': 88,
#    'pod': 'd',
#    'timestamp_utc': '2022-08-10T19:00:00',
#    'pres': 1015.5,
#    'solar_rad': 663.368,
#    'ozone': 316.8,
#    'weather': {'icon': 'c03d', 'code': 803, 'description': 'Broken clouds'},
#    'wind_gust_spd': 10.21,
#    'timestamp_local': '2022-08-10T12:00:00',
#    'snow_depth': 0,
#    'clouds': 61,
#    'ts': 1660158000,
#    'wind_spd': 7.74,
#    'pop': 0,
#    'wind_cdir_full': 'south-southwest',
#    'slp': 1017.5,
#    'dni': 888.46,
#    'dewpt': 13.5,
#    'snow': 0,
#    'uv': 4.2,
#    'wind_dir': 209,
#    'clouds_hi': 0,
#    'precip': 0,
#    'vis': 24.128,
#    'dhi': 115.59,
#    'app_temp': 15.5,
#    'datetime': '2022-08-10:19',
#    'temp': 15.5,
#    'ghi': 832.62,
#    'clouds_mid': 0,
#    'clouds_low': 61},
#   {'wind_cdir': 'SSW',
#    'rh': 86,
#    'pod': 'd',
#    'timestamp_utc': '2022-08-10T20:00:00',
#    'pres': 1015.5,
#    'solar_rad': 846.597,
#    'ozone': 319,
#    'weather': {'icon': 'c02d', 'code': 801, 'description': 'Few clouds'},
#    'wind_gust_spd': 11.2,
#    'timestamp_local': '2022-08-10T13:00:00',
#    'snow_depth': 0,
#    'clouds': 6,
#    'ts': 1660161600,
#    'wind_spd': 8.3,
#    'pop': 0,
#    'wind_cdir_full': 'south-southwest',
#    'slp': 1017.5,
#    'dni': 900.09,
#    'dewpt': 13.3,
#    'snow': 0,
#    'uv': 7.6,
#    'wind_dir': 211,
#    'clouds_hi': 0,
#    'precip': 0,
#    'vis': 24.128,
#    'dhi': 118.07,
#    'app_temp': 15.6,
#    'datetime': '2022-08-10:20',
#    'temp': 15.6,
#    'ghi': 879.32,
#    'clouds_mid': 0,
#    'clouds_low': 6},
#   {'wind_cdir': 'SSW',
#    'rh': 83,
#    'pod': 'd',
#    'timestamp_utc': '2022-08-10T21:00:00',
#    'pres': 1016,
#    'solar_rad': 839.421,
#    'ozone': 320.5,
#    'weather': {'icon': 'c02d', 'code': 801, 'description': 'Few clouds'},
#    'wind_gust_spd': 11.41,
#    'timestamp_local': '2022-08-10T14:00:00',
#    'snow_depth': 0,
#    'clouds': 3,
#    'ts': 1660165200,
#    'wind_spd': 8.18,
#    'pop': 0,
#    'wind_cdir_full': 'south-southwest',
#    'slp': 1018,
#    'dni': 898.23,
#    'dewpt': 13.4,
#    'snow': 0,
#    'uv': 7.7,
#    'wind_dir': 213,
#    'clouds_hi': 0,
#    'precip': 0,
#    'vis': 24.128,
#    'dhi': 117.67,
#    'app_temp': 16.3,
#    'datetime': '2022-08-10:21',
#    'temp': 16.3,
#    'ghi': 871.63,
#    'clouds_mid': 0,
#    'clouds_low': 3},
#   {'wind_cdir': 'SW',
#    'rh': 85,
#    'pod': 'd',
#    'timestamp_utc': '2022-08-10T22:00:00',
#    'pres': 1016,
#    'solar_rad': 780.256,
#    'ozone': 319.5,
#    'weather': {'icon': 'c01d', 'code': 800, 'description': 'Clear Sky'},
#    'wind_gust_spd': 10.31,
#    'timestamp_local': '2022-08-10T15:00:00',
#    'snow_depth': 0,
#    'clouds': 0,
#    'ts': 1660168800,
#    'wind_spd': 7.15,
#    'pop': 0,
#    'wind_cdir_full': 'southwest',
#    'slp': 1018,
#    'dni': 882.61,
#    'dewpt': 13.4,
#    'snow': 0,
#    'uv': 6.8,
#    'wind_dir': 216,
#    'clouds_hi': 0,
#    'precip': 0,
#    'vis': 24.128,
#    'dhi': 114.36,
#    'app_temp': 15.9,
#    'datetime': '2022-08-10:22',
#    'temp': 15.9,
#    'ghi': 810.2,
#    'clouds_mid': 0,
#    'clouds_low': 0}]}

# %%
aqi_test['station_name'=='Columbia River entrance (N. Jetty)']
# Out:
# '46.2733'

# %%
keys = ['lat','long']
latlong = [float(aqi_data['station_name'=='Columbia River entrance (N. Jetty)'][key]) for key in keys]

# %%
latlong
# Out:
# [46.2733, -124.072]

# %%
[item['station_name'] for item in aqi_test]
# Out:
# ['Columbia River entrance (N. Jetty)',
#  'Cape Disappointment',
#  "Fort Canby, Jetty 'A', Wash.",
#  'Ilwaco, Baker Bay, Wash.',
#  'Chinook, Baker Bay, Wash.',
#  'Hungry Harbor, Wash.',
#  'Hammond, Oregon',
#  'Point Adams, Oreg.',
#  'Astoria (Youngs Bay), Oreg.',
#  'Cathcart Landing, Youngs River',
#  'Warrenton, Skipanon River, Oreg.',
#  'Astoria (Port Docks), Oreg.',
#  'ASTORIA (Tongue Point), Oreg.',
#  'Knappa, Knappa Slough',
#  'Settlers Point, Oreg.',
#  'Harrington Point, Wash.',
#  'Skamokawa',
#  'Wauna',
#  'Cape Horn',
#  'Barlow Point',
#  'Longview',
#  'Temco Kalama Terminal',
#  'Saint Helens',
#  'Knapp Landing, Willow Bar',
#  'Rocky Point',
#  'Portland Morrison Street Bridge',
#  'Vancouver',
#  'Washougal',
#  'Beacon Rock State Park',
#  'Nahcotta',
#  'Tarlatt Slough',
#  'Greenhead Slough',
#  'Paradise Point, Long Island',
#  'Naselle River, swing bridge',
#  'Naselle River, 4 miles above swing bridge',
#  'Bay Center, Palix River',
#  'Palix River, south fork',
#  'TOKE POINT',
#  'Mailboat Slough, Willapa River',
#  'South Bend, Willapa River',
#  'Raymond, Willapa River',
#  'Westport, Point Chehalis',
#  'Point Brown',
#  'Bay City, South Bay',
#  'Markham',
#  'ABERDEEN',
#  'Cosmopolis, Chehalis River',
#  'Montesano, Chehalis River',
#  'Point Grenville',
#  'Destruction Island',
#  'James Island',
#  'La Push, Quillayute River',
#  'Tskawahyah Island, Cape Alava',
#  'Makah Bay',
#  'Tatoosh Island, Cape Flattery',
#  'NEAH BAY',
#  'Sekiu, Clallam Bay',
#  'Jim Creek',
#  'Twin Rivers',
#  'Crescent Bay',
#  'Port Angeles',
#  'Ediz Hook, Port Angeles',
#  'Dungeness',
#  'Sequim Bay entrance',
#  'Gardiner, Discovery Bay',
#  'Smith Island',
#  'Point Partridge, Whidbey Island',
#  'Sunset Beach, Whidbey Island',
#  'NAS Whidbey Island',
#  'Admiralty Head',
#  'PORT TOWNSEND',
#  'Marrowstone Point',
#  'Mystery Bay, Marrowstone Island',
#  'Bush Point, Whidbey Island',
#  'Port Ludlow',
#  'Foulweather Bluff',
#  'Port Gamble',
#  'Lofall',
#  'Bangor Wharf',
#  'Zelatched Point, Dabob Bay',
#  'Whitney Point, Dabob Bay',
#  'Quilcene, Quilcene Bay, Dabob Bay',
#  'Seabeck, Seabeck Bay',
#  'Pleasant Harbor',
#  'Triton Head',
#  'Ayock Point',
#  'Union',
#  'Lynch Cove Dock',
#  'Hansville',
#  'Edmonds',
#  'Kingston, Appletree Cove',
#  'Port Jefferson',
#  'Port Madison',
#  'Meadow Point, Shilshole Bay',
#  'Poulsbo, Liberty Bay',
#  'Brownsville, Port Orchard',
#  'SEATTLE (Madison St.), Elliott Bay',
#  'Lockheed Shipyard, Harbor Island',
#  'Duwamish Waterway, Eighth Ave. South',
#  'Eagle Harbor, Bainbridge Island',
#  'Port Blakely',
#  'Clam Bay, Rich Passage',
#  'Bremerton, Sinclair Inlet, Port Orchard',
#  'Tracyton, Dyes Inlet',
#  'Harper, Yukon Harbor',
#  'Point Vashon, Vashon Island',
#  'Des Moines, East Passage',
#  'Burton, Quartermaster Hbr. (inside), Vashon I.',
#  'Tahlequah, Neil Pt., Dalco Passage, Vashon I.',
#  'Gig Harbor',
#  'Tacoma, Commencement Bay, Sitcum Waterway',
#  'Tacoma Narrows Bridge',
#  'Arletta, Hale Passage',
#  'Horsehead Bay, Carr Inlet',
#  'Wauna, Carr Inlet',
#  'Home, Von Geldern Cove, Carr Inlet',
#  'Steilacoom, Cormorant Passage',
#  'Yoman Point, Anderson Island, Balch Passage',
#  'SANDY POINT ANDERSON ISLAND, PUGET SOUND',
#  'Dupont Wharf, Nisqually Reach',
#  'Longbranch, Filucy Bay',
#  'Devils Head, Drayton Passage',
#  'Henderson Inlet',
#  'McMicken Island, Case Inlet',
#  'Vaughn, Case Inlet',
#  'Allyn, Case Inlet',
#  'Walkers Landing, Pickering Passage',
#  'Shelton, Oakland Bay',
#  'Arcadia, Totten Inlet',
#  'Barron Point, Little Snookum Inlet Entrance',
#  'Rocky Point, Eld Inlet',
#  'Dofflemeyer Point, Boston Hbr., Budd Inlet',
#  'Budd Inlet, Olympia Shoal',
#  'Olympia, Budd Inlet',
#  'Glendale, Whidbey Island',
#  'Everett',
#  'Marysville, Quilceda Creek',
#  'Priest Point',
#  'Tulalip',
#  'Spee-Bi-Dah',
#  'Tulare Beach, Port Susan',
#  'Kayak Point',
#  'Stanwood, Stillaguamish River',
#  'Sandy Point, Whidbey Island',
#  'Holly Farms Harbor, Holmes Harbor, Whidbey I.',
#  'Greenbank, Whidbey Island',
#  'Crescent Harbor, N. Whidbey Island',
#  'Coupeville, Penn Cove, Whidbey Island',
#  'La Conner, Swinomish Channel',
#  'Sneeoosh Point',
#  'Turner Bay, Similk Bay',
#  'Ala Spit, Whidbey Island',
#  'Yokeko Point, Deception Pass',
#  'Cornet Bay, Deception Pass',
#  'Deception Pass St. Park, Bowman Bay, Fidalgo I.',
#  'Aleck Bay, Lopez Island',
#  'TELEGRAPH BAY, PUGET SOUND',
#  'Burrows Bay (Allan Island)',
#  'Ship Harbor, Fidalgo Island',
#  'Anacortes, Guemes Channel',
#  'Swinomish Channel ent., Padilla Bay',
#  'Armitage Island, Thatcher Pass',
#  'Strawberry Bay, Cypress Island',
#  'Peavine Pass',
#  'Tide Point, Cypress Island',
#  'Gooseberry Point',
#  'Point Migley',
#  'Chuckanut Bay',
#  'Bellingham',
#  'Village Point, Lummi Island',
#  'Sandy Point, Lummi Bay',
#  'Rosario, East Sound, Orcas Island',
#  'Upright Head, Lopez Island',
#  'Orcas, Orcas Island',
#  'Richardson, Lopez Island',
#  'Shaw Island, Ferry Terminal, Harney Channel',
#  'Friday Harbor, San Juan Island',
#  'Echo Bay, Sucia Islands',
#  'Ferndale',
#  'CHERRY POINT',
#  'Blaine, Semiahmoo Bay',
#  'POINT ROBERTS, PUGET SOUND',
#  'Kanaka Bay, San Juan Island',
#  'Hanbury Point, Mosquito Pass, San Juan I.',
#  'Roche Harbor, San Juan Island',
#  'WALDRON ISLAND, PUGET SOUND',
#  'Patos Island Wharf']

# %%
wind = [i['wind_spd'] for i in aqi_test]
date_times = [i['datetime'].split(":") for i in aqi_test]
date = pd.to_datetime([i[0] for i in date_times])
hour = pd.Series([i[1] for i in date_times])
date_times = date + hour.astype("timedelta64[h]")
wind_dict = {'dts':date_times, 'wind':wind}
wind_df = pd.DataFrame(wind_dict)
wind_df_filtered = wind_df[wind_df.dts.dt.date == d]

# %%
d = '2022-08-05'

# %%
pd.to_datetime(df.DATE) + df.HOUR.astype('timedelta64[h]')

# %%
import datetime
today = date.today()
end_date = today + datetime.timedelta(days=3)
begin_date={today.strftime('%Y%m%d')}& \
end_date={end_date.strftime('%Y%m%d')}& \

# %%
dt = 1660039200
pd.to_datetime(dt, unit='s', origin='unix')
# Out:
# Timestamp('2022-08-09 10:00:00')

# %%
#pull data from MongoDB and make a dataframe
import pandas as pd
cursor = weather.find()
list_cur = list(cursor)
weather_df = pd.DataFrame(list_cur)

# %%
weather_df.head()
# Out:
#                         _id  \
# 0  62ed406dc868aa58a7094f6e
#
#                   Columbia River entrance (N. Jetty)  \
# 0  {'station_id': '9440574', 'lat': '+46.2733', '...
#
#                                  Cape Disappointment  \
# 0  {'station_id': '9440581', 'lat': '+46.2810', '...
#
#                         Fort Canby, Jetty 'A', Wash.  \
# 0  {'station_id': '9440572', 'lat': '+46.2683', '...
#
#                             Ilwaco, Baker Bay, Wash.  \
# 0  {'station_id': '9440597', 'lat': '+46.3033', '...
#
#                            Chinook, Baker Bay, Wash.  \
# 0  {'station_id': '9440573', 'lat': '+46.2717', '...
#
#                                 Hungry Harbor, Wash.  \
# 0  {'station_id': '9440563', 'lat': '+46.2583', '...
#
#                                      Hammond, Oregon  \
# 0  {'station_id': '9439011', 'lat': '+46.2017', '...
#
#                                   Point Adams, Oreg.  \
# 0  {'station_id': 'TWC0881', 'lat': '+46.2000', '...
#
#                          Astoria (Youngs Bay), Oreg.  ...  \
# 0  {'station_id': '9439026', 'lat': '+46.1717', '...  ...
#
#                              Echo Bay, Sucia Islands  \
# 0  {'station_id': '9449712', 'lat': '+48.7567', '...
#
#                                             Ferndale  \
# 0  {'station_id': 'TWC1189', 'lat': '+48.8333', '...
#
#                                         CHERRY POINT  \
# 0  {'station_id': '9449424', 'lat': '+48.8633', '...
#
#                                Blaine, Semiahmoo Bay  \
# 0  {'station_id': '9449679', 'lat': '+48.9917', '...
#
#                           POINT ROBERTS, PUGET SOUND  \
# 0  {'station_id': '9449639', 'lat': '+48.9750', '...
#
#                          Kanaka Bay, San Juan Island  \
# 0  {'station_id': '9449856', 'lat': '+48.4850', '...
#
#            Hanbury Point, Mosquito Pass, San Juan I.  \
# 0  {'station_id': '9449828', 'lat': '+48.5817', '...
#
#                        Roche Harbor, San Juan Island  \
# 0  {'station_id': '9449834', 'lat': '+48.6100', '...
#
#                          WALDRON ISLAND, PUGET SOUND  \
# 0  {'station_id': '9449746', 'lat': '+48.6868', '...
#
#                                   Patos Island Wharf
# 0  {'station_id': '9449704', 'lat': '+48.7867', '...
#
# [1 rows x 188 columns]

# %%
weather_df.head()
# Out:
#                         _id  \
# 0  62ed406dc868aa58a7094f6e
#
#                   Columbia River entrance (N. Jetty)  \
# 0  {'station_id': '9440574', 'lat': '+46.2733', '...
#
#                                  Cape Disappointment  \
# 0  {'station_id': '9440581', 'lat': '+46.2810', '...
#
#                         Fort Canby, Jetty 'A', Wash.  \
# 0  {'station_id': '9440572', 'lat': '+46.2683', '...
#
#                             Ilwaco, Baker Bay, Wash.  \
# 0  {'station_id': '9440597', 'lat': '+46.3033', '...
#
#                            Chinook, Baker Bay, Wash.  \
# 0  {'station_id': '9440573', 'lat': '+46.2717', '...
#
#                                 Hungry Harbor, Wash.  \
# 0  {'station_id': '9440563', 'lat': '+46.2583', '...
#
#                                      Hammond, Oregon  \
# 0  {'station_id': '9439011', 'lat': '+46.2017', '...
#
#                                   Point Adams, Oreg.  \
# 0  {'station_id': 'TWC0881', 'lat': '+46.2000', '...
#
#                          Astoria (Youngs Bay), Oreg.  ...  \
# 0  {'station_id': '9439026', 'lat': '+46.1717', '...  ...
#
#                              Echo Bay, Sucia Islands  \
# 0  {'station_id': '9449712', 'lat': '+48.7567', '...
#
#                                             Ferndale  \
# 0  {'station_id': 'TWC1189', 'lat': '+48.8333', '...
#
#                                         CHERRY POINT  \
# 0  {'station_id': '9449424', 'lat': '+48.8633', '...
#
#                                Blaine, Semiahmoo Bay  \
# 0  {'station_id': '9449679', 'lat': '+48.9917', '...
#
#                           POINT ROBERTS, PUGET SOUND  \
# 0  {'station_id': '9449639', 'lat': '+48.9750', '...
#
#                          Kanaka Bay, San Juan Island  \
# 0  {'station_id': '9449856', 'lat': '+48.4850', '...
#
#            Hanbury Point, Mosquito Pass, San Juan I.  \
# 0  {'station_id': '9449828', 'lat': '+48.5817', '...
#
#                        Roche Harbor, San Juan Island  \
# 0  {'station_id': '9449834', 'lat': '+48.6100', '...
#
#                          WALDRON ISLAND, PUGET SOUND  \
# 0  {'station_id': '9449746', 'lat': '+48.6868', '...
#
#                                   Patos Island Wharf
# 0  {'station_id': '9449704', 'lat': '+48.7867', '...
#
# [1 rows x 188 columns]

# %%
#show wind, temp, clouds for the next 24 hours
weather_df[['timestamp_local','wind_spd','temp','clouds']].head(5)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-126-c6e8d1e313bc> in <module>
#       1 #show wind, temp, clouds for the next 24 hours
# ----> 2 weather_df[['timestamp_local','wind_spd','temp','clouds']].head(5)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3028             if is_iterator(key):
#    3029                 key = list(key)
# -> 3030             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    3031
#    3032         # take() does not accept boolean indexers
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1264             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1265
# -> 1266         self._validate_read_indexer(keyarr, indexer, axis, raise_missing=raise_missing)
#    1267         return keyarr, indexer
#    1268
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1306             if missing == len(indexer):
#    1307                 axis_name = self.obj._get_axis_name(axis)
# -> 1308                 raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    1309
#    1310             ax = self.obj._get_axis(axis)
#
# KeyError: "None of [Index(['timestamp_local', 'wind_spd', 'temp', 'clouds'], dtype='object')] are in the [columns]"
